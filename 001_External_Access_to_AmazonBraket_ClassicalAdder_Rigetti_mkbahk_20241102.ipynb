# %% [markdown]
# # 작업순서
# 1. Amazon Braket 환경 설정(확인만)
# 2. S3 환경설정(확인만)
# 3. (중요) IAM을 이용한 Access Key 설정 및 권한 부여
# 4. 원격 작업
# 5. 각종 로그 보기
# 6. 작업 환경 정리

# %%
#!pip install git+https://github.com/qiskit-community/qiskit-braket-provider.git

# %%
# !pip install qiskit-braket-provider==0.7.0
# !pip install amazon-braket-sdk==1.104.1
#!pip install amazon-braket-sdk==1.94.0
#!python3 -m pip install boto3
#!python3 -m pip install botocore
# Out:
# Requirement already satisfied: qiskit-braket-provider==0.7.0 in /usr/local/lib/python3.12/dist-packages (0.7.0)
# Requirement already satisfied: certifi>=2021.5.30 in /usr/local/lib/python3.12/dist-packages (from qiskit-braket-provider==0.7.0) (2025.10.5)
# Requirement already satisfied: qiskit>=0.34.2 in /usr/local/lib/python3.12/dist-packages (from qiskit-braket-provider==0.7.0) (2.2.3)
# Requirement already satisfied: qiskit-ionq>=0.5.2 in /usr/local/lib/python3.12/dist-packages (from qiskit-braket-provider==0.7.0) (1.0.2)
# Requirement already satisfied: amazon-braket-sdk>=1.99.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-braket-provider==0.7.0) (1.104.1)
# Requirement already satisfied: setuptools>=40.1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-braket-provider==0.7.0) (75.2.0)
# Requirement already satisfied: numpy>=1.3 in /usr/local/lib/python3.12/dist-packages (from qiskit-braket-provider==0.7.0) (2.0.2)
# Requirement already satisfied: amazon-braket-schemas>=1.26.1 in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (1.26.1)
# Requirement already satisfied: amazon-braket-default-simulator>=1.32.0 in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (1.32.0)
# Requirement already satisfied: oqpy~=0.3.7 in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (0.3.9)
# Requirement already satisfied: backoff in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (2.2.1)
# Requirement already satisfied: boltons in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (25.0.0)
# Requirement already satisfied: boto3>=1.28.53 in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (1.40.67)
# Requirement already satisfied: cloudpickle==2.2.1 in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (2.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (1.6.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (3.5)
# Requirement already satisfied: openpulse in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (1.0.1)
# Requirement already satisfied: openqasm3 in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (1.0.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (1.13.3)
# Requirement already satisfied: backports.entry-points-selectable in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (1.3.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.34.2->qiskit-braket-provider==0.7.0) (0.17.1)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.34.2->qiskit-braket-provider==0.7.0) (1.16.3)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.34.2->qiskit-braket-provider==0.7.0) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.34.2->qiskit-braket-provider==0.7.0) (5.5.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.34.2->qiskit-braket-provider==0.7.0) (4.15.0)
# Requirement already satisfied: decorator>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-ionq>=0.5.2->qiskit-braket-provider==0.7.0) (5.2.1)
# Requirement already satisfied: requests>=2.24.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-ionq>=0.5.2->qiskit-braket-provider==0.7.0) (2.32.4)
# Requirement already satisfied: importlib-metadata>=4.11.4 in /usr/local/lib/python3.12/dist-packages (from qiskit-ionq>=0.5.2->qiskit-braket-provider==0.7.0) (8.7.0)
# Requirement already satisfied: python-dotenv>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from qiskit-ionq>=0.5.2->qiskit-braket-provider==0.7.0) (1.2.1)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (0.60.0)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.12/dist-packages (from amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (3.4.0)
# Requirement already satisfied: pydantic>2 in /usr/local/lib/python3.12/dist-packages (from amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (2.11.10)
# Requirement already satisfied: antlr4-python3-runtime==4.13.2 in /usr/local/lib/python3.12/dist-packages (from amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (4.13.2)
# Requirement already satisfied: botocore<1.41.0,>=1.40.67 in /usr/local/lib/python3.12/dist-packages (from boto3>=1.28.53->amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (1.40.67)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from boto3>=1.28.53->amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (1.0.1)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from boto3>=1.28.53->amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (0.14.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata>=4.11.4->qiskit-ionq>=0.5.2->qiskit-braket-provider==0.7.0) (3.23.0)
# Requirement already satisfied: mypy-extensions>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from oqpy~=0.3.7->amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (1.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.24.0->qiskit-ionq>=0.5.2->qiskit-braket-provider==0.7.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.24.0->qiskit-ionq>=0.5.2->qiskit-braket-provider==0.7.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.24.0->qiskit-ionq>=0.5.2->qiskit-braket-provider==0.7.0) (2.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (1.3.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from botocore<1.41.0,>=1.40.67->boto3>=1.28.53->amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (2.9.0.post0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>2->amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>2->amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>2->amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (0.4.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.41.0,>=1.40.67->boto3>=1.28.53->amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (1.17.0)
# Requirement already satisfied: amazon-braket-sdk==1.104.1 in /usr/local/lib/python3.12/dist-packages (1.104.1)
# Requirement already satisfied: amazon-braket-schemas>=1.26.1 in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk==1.104.1) (1.26.1)
# Requirement already satisfied: amazon-braket-default-simulator>=1.32.0 in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk==1.104.1) (1.32.0)
# Requirement already satisfied: oqpy~=0.3.7 in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk==1.104.1) (0.3.9)
# Requirement already satisfied: backoff in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk==1.104.1) (2.2.1)
# Requirement already satisfied: boltons in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk==1.104.1) (25.0.0)
# Requirement already satisfied: boto3>=1.28.53 in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk==1.104.1) (1.40.67)
# Requirement already satisfied: cloudpickle==2.2.1 in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk==1.104.1) (2.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk==1.104.1) (1.6.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk==1.104.1) (3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk==1.104.1) (2.0.2)
# Requirement already satisfied: openpulse in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk==1.104.1) (1.0.1)
# Requirement already satisfied: openqasm3 in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk==1.104.1) (1.0.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk==1.104.1) (1.13.3)
# Requirement already satisfied: backports.entry-points-selectable in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk==1.104.1) (1.3.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk==1.104.1) (0.60.0)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.12/dist-packages (from amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk==1.104.1) (3.4.0)
# Requirement already satisfied: pydantic>2 in /usr/local/lib/python3.12/dist-packages (from amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk==1.104.1) (2.11.10)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk==1.104.1) (1.16.3)
# Requirement already satisfied: antlr4-python3-runtime==4.13.2 in /usr/local/lib/python3.12/dist-packages (from amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk==1.104.1) (4.13.2)
# Requirement already satisfied: botocore<1.41.0,>=1.40.67 in /usr/local/lib/python3.12/dist-packages (from boto3>=1.28.53->amazon-braket-sdk==1.104.1) (1.40.67)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from boto3>=1.28.53->amazon-braket-sdk==1.104.1) (1.0.1)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from boto3>=1.28.53->amazon-braket-sdk==1.104.1) (0.14.0)
# Requirement already satisfied: mypy-extensions>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from oqpy~=0.3.7->amazon-braket-sdk==1.104.1) (1.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->amazon-braket-sdk==1.104.1) (1.3.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from botocore<1.41.0,>=1.40.67->boto3>=1.28.53->amazon-braket-sdk==1.104.1) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.12/dist-packages (from botocore<1.41.0,>=1.40.67->boto3>=1.28.53->amazon-braket-sdk==1.104.1) (2.5.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>2->amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk==1.104.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>2->amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk==1.104.1) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>2->amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk==1.104.1) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>2->amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk==1.104.1) (0.4.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk==1.104.1) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.41.0,>=1.40.67->boto3>=1.28.53->amazon-braket-sdk==1.104.1) (1.17.0)

# %%
# %pip show qiskit
# %pip show qiskit-braket-provider
# %pip show amazon-braket-sdk
# Out:
# Name: qiskit
# Version: 2.2.3
# Summary: An open-source SDK for working with quantum computers at the level of extended quantum circuits, operators, and primitives.
# Home-page: https://www.ibm.com/quantum/qiskit
# Author:
# Author-email: Qiskit Development Team <qiskit@us.ibm.com>
# License: Apache 2.0
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: dill, numpy, rustworkx, scipy, stevedore, typing-extensions
# Required-by: qiskit-ionq, qiskit_braket_provider
# Name: qiskit_braket_provider
# Version: 0.7.0
# Summary: Qiskit-Braket provider to execute Qiskit programs on AWS quantum computing hardware devices through Amazon Braket.
# Home-page:
# Author:
# Author-email:
# License:
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: amazon-braket-sdk, certifi, numpy, qiskit, qiskit-ionq, setuptools
# Required-by:
# Name: amazon-braket-sdk
# Version: 1.104.1
# Summary: An open source library for interacting with quantum computing devices on Amazon Braket
# Home-page: https://github.com/amazon-braket/amazon-braket-sdk-python
# Author: Amazon Web Services
# Author-email:
# License: Apache License 2.0
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: amazon-braket-default-simulator, amazon-braket-schemas, backoff, backports.entry-points-selectable, boltons, boto3, cloudpickle, nest-asyncio, networkx, numpy, openpulse, openqasm3, oqpy, sympy
# Required-by: qiskit_braket_provider

# %%
from braket.experimental_capabilities import EnableExperimentalCapability

# %%
import warnings

# warnings 모듈을 사용하여 특정 경고 메시지를 무시합니다.
warnings.filterwarnings('ignore')

# %%
# Use Braket SDK Cost Tracking to estimate the cost to run this example
from braket.tracking import Tracker
t = Tracker().start()

# %%
import os
# Set environment variables for AWS credentials
os.environ['AWS_ACCESS_KEY_ID'] = ""
os.environ['AWS_SECRET_ACCESS_KEY'] = ""
os.environ['AWS_DEFAULT_REGION'] = "us-east-1"

# You can optionally set the s3 bucket and prefix using environment variables
#os.environ['AWS_BRAKET_S3_BUCKET'] = "snuqc"
#os.environ['AWS_BRAKET_S3_PREFIX'] = "amazonbraket"

# %%
from qiskit_braket_provider import BraketLocalBackend

local_simulator = BraketLocalBackend()
#local_sv_simulator = BraketLocalBackend(name='braket_sv')
#local_dm_simulator = BraketLocalBackend(name='braket_dm')

# %%
from qiskit_braket_provider import BraketProvider

provider = BraketProvider()
#provider.backends(statuses=["ONLINE"], types=["SIMULATOR"])
#provider.backends(statuses=["ONLINE"], types=["QPU"])
provider.backends(statuses=["ONLINE"], types=["SIMULATOR", "QPU"])
# Out:
# [BraketBackend[Ankaa-3],
#  BraketBackend[Emerald],
#  BraketBackend[Forte 1],
#  BraketBackend[Garnet],
#  BraketBackend[SV1],
#  BraketBackend[TN1],
#  BraketBackend[dm1]]

# %%
#backend = provider.get_backend("Aria 1")
#backend = provider.get_backend("Aria 2")
#backend = provider.get_backend("Forte 1")

backend= provider.get_backend("Ankaa-3")
#backend = provider.get_backend("Aspen-M-3")

#Ibackend = provider.get_backend("Garnet")

#backend = provider.get_backend("SV1")
#backend = provider.get_backend("dm1")
#backend = provider.get_backend("TN1")

# %%
from qiskit import QuantumCircuit

# 양자 회로 생성
circuit = QuantumCircuit(5, 5)  # 5개의 양자 비트와 2개의 클래식 비트를 사용합니다.

# 입력 비트 설정 (A=1, B=1)
circuit.x(0)  # A 비트를 1로 설정
circuit.x(1)  # B 비트를 1로 설정
circuit.barrier()

# 반-가산기 회로 구현
circuit.cx(0, 3) # XOR 게이트 (A와 B의 논리합)
circuit.cx(1, 3) # XOR 게이트 (A와 B의 논리합)
circuit.ccx(0, 1, 4) # AND 게이트 (A와 B의 논리곱)
circuit.cx(2, 3) # XOR 게이트 (A와 B의 논리합)
circuit.ccx(0, 2, 4) # AND 게이트 (A와 B의 논리곱)
circuit.ccx(1, 2, 4) # AND 게이트 (A와 B의 논리곱)
circuit.barrier()

# 결과를 측정하여 Sum과 Carry 출력을 얻습니다.
circuit.measure(0, 4)  # 큐비트를 클래식 비트 4에 매핑
circuit.measure(1, 3)  # 큐비트를 클래식 비트 3에 매핑
circuit.measure(2, 2)  # 보조비트를 클래식 비트 2에 매핑
circuit.measure(3, 1)  # Sum(Result) 비트를 클래식 비트 1에 매핑
circuit.measure(4, 0)  # Carry 비트를 클래식 비트 0에 매핑

# %%
circuit.draw()
# Out:
#      ┌───┐ ░                                ░ ┌─┐
# q_0: ┤ X ├─░───■─────────■─────────■────────░─┤M├────────────
#      ├───┤ ░   │         │         │        ░ └╥┘┌─┐
# q_1: ┤ X ├─░───┼────■────■─────────┼────■───░──╫─┤M├─────────
#      └───┘ ░   │    │    │         │    │   ░  ║ └╥┘┌─┐
# q_2: ──────░───┼────┼────┼────■────■────■───░──╫──╫─┤M├──────
#            ░ ┌─┴─┐┌─┴─┐  │  ┌─┴─┐  │    │   ░  ║  ║ └╥┘┌─┐
# q_3: ──────░─┤ X ├┤ X ├──┼──┤ X ├──┼────┼───░──╫──╫──╫─┤M├───
#            ░ └───┘└───┘┌─┴─┐└───┘┌─┴─┐┌─┴─┐ ░  ║  ║  ║ └╥┘┌─┐
# q_4: ──────░───────────┤ X ├─────┤ X ├┤ X ├─░──╫──╫──╫──╫─┤M├
#            ░           └───┘     └───┘└───┘ ░  ║  ║  ║  ║ └╥┘
# c: 5/══════════════════════════════════════════╩══╩══╩══╩══╩═
#                                                4  3  2  1  0

# %%
from qiskit.compiler import transpile, assemble
trans_qc = transpile(circuit, backend)
trans_qc.draw()
# Out:
#                                                                                »
#   ancilla_0 -> 0 ──────────────────────────────────────────────────────────────»
#                                                                                »
#   ancilla_1 -> 1 ──────────────────────────────────────────────────────────────»
#                                                                                »
#   ancilla_2 -> 2 ──────────────────────────────────────────────────────────────»
#                                                                                »
#   ancilla_3 -> 3 ──────────────────────────────────────────────────────────────»
#                                                                                »
#   ancilla_4 -> 4 ──────────────────────────────────────────────────────────────»
#                                                                                »
#   ancilla_5 -> 5 ──────────────────────────────────────────────────────────────»
#                                                                                »
#   ancilla_6 -> 6 ──────────────────────────────────────────────────────────────»
#                                                                                »
#   ancilla_7 -> 7 ──────────────────────────────────────────────────────────────»
#                                                                                »
#   ancilla_8 -> 8 ──────────────────────────────────────────────────────────────»
#                                                                                »
#   ancilla_9 -> 9 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_10 -> 10 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_11 -> 11 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_12 -> 12 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_13 -> 13 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_14 -> 14 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_15 -> 15 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_16 -> 16 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_17 -> 17 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_18 -> 18 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_19 -> 19 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_20 -> 20 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_21 -> 21 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_22 -> 22 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_23 -> 23 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_24 -> 24 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_25 -> 25 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_26 -> 26 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_27 -> 27 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_28 -> 28 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_29 -> 29 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_30 -> 30 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_31 -> 31 ──────────────────────────────────────────────────────────────»
#                        ░                                                       »
#        q_2 -> 32 ──────░─────────────■─────X───────────────────────────────────»
#                        ░ ┌───┐┌───┐┌─┴─┐   │                                   »
#        q_3 -> 33 ──────░─┤ X ├┤ X ├┤ X ├───X───────────────────────────────────»
#                  ┌───┐ ░ └─┬─┘└─┬─┘└───┘                                       »
#        q_0 -> 34 ┤ X ├─░───■────┼────────────────■─────────────────────■───────»
#                  └───┘ ░        │                │                     │       »
# ancilla_32 -> 35 ───────────────┼────────────────┼─────────────────────┼───────»
#                                 │                │                     │       »
# ancilla_33 -> 36 ───────────────┼────────────────┼─────────────────────┼───────»
#                                 │                │                     │       »
# ancilla_34 -> 37 ───────────────┼────────────────┼─────────────────────┼───────»
#                                 │                │                     │       »
# ancilla_35 -> 38 ───────────────┼────────────────┼─────────────────────┼───────»
#                                 │                │                     │       »
# ancilla_36 -> 39 ───────────────┼────────────────┼─────────────────────┼───────»
#                  ┌───┐ ░        │                │             ┌───┐   │       »
#        q_1 -> 40 ┤ X ├─░────────■────■───────────┼─────────■───┤ T ├───┼───────»
#                  └───┘ ░ ┌───┐     ┌─┴─┐┌─────┐┌─┴─┐┌───┐┌─┴─┐┌┴───┴┐┌─┴─┐┌───┐»
#        q_4 -> 41 ──────░─┤ H ├─────┤ X ├┤ Tdg ├┤ X ├┤ T ├┤ X ├┤ Tdg ├┤ X ├┤ T ├»
#                        ░ └───┘     └───┘└─────┘└───┘└───┘└───┘└─────┘└───┘└───┘»
# ancilla_37 -> 42 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_38 -> 43 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_39 -> 44 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_40 -> 45 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_41 -> 46 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_42 -> 47 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_43 -> 48 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_44 -> 49 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_45 -> 50 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_46 -> 51 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_47 -> 52 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_48 -> 53 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_49 -> 54 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_50 -> 55 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_51 -> 56 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_52 -> 57 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_53 -> 58 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_54 -> 59 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_55 -> 60 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_56 -> 61 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_57 -> 62 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_58 -> 63 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_59 -> 64 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_60 -> 65 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_61 -> 66 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_62 -> 67 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_63 -> 68 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_64 -> 69 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_65 -> 70 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_66 -> 71 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_67 -> 72 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_68 -> 73 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_69 -> 74 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_70 -> 75 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_71 -> 76 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_72 -> 77 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_73 -> 78 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_74 -> 79 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_75 -> 80 ──────────────────────────────────────────────────────────────»
#                                                                                »
# ancilla_76 -> 81 ──────────────────────────────────────────────────────────────»
#                                                                                »
#             c: 5/══════════════════════════════════════════════════════════════»
#                                                                                »
# «                                                                           »
# «  ancilla_0 -> 0 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «  ancilla_1 -> 1 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «  ancilla_2 -> 2 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «  ancilla_3 -> 3 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «  ancilla_4 -> 4 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «  ancilla_5 -> 5 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «  ancilla_6 -> 6 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «  ancilla_7 -> 7 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «  ancilla_8 -> 8 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «  ancilla_9 -> 9 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_10 -> 10 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_11 -> 11 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_12 -> 12 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_13 -> 13 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_14 -> 14 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_15 -> 15 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_16 -> 16 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_17 -> 17 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_18 -> 18 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_19 -> 19 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_20 -> 20 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_21 -> 21 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_22 -> 22 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_23 -> 23 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_24 -> 24 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_25 -> 25 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_26 -> 26 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_27 -> 27 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_28 -> 28 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_29 -> 29 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_30 -> 30 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_31 -> 31 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «       q_2 -> 32 ──────────────────────────────────────────────────────────»
# «                                                        ┌───┐              »
# «       q_3 -> 33 ─────■─────────────────────────────■───┤ T ├────────────X─»
# «                    ┌─┴─┐ ┌─────┐       ┌───┐┌───┐┌─┴─┐┌┴───┴┐┌───┐┌───┐ │ »
# «       q_0 -> 34 ─X─┤ X ├─┤ Tdg ├───────┤ X ├┤ T ├┤ X ├┤ Tdg ├┤ X ├┤ T ├─X─»
# «                  │ └───┘ └─────┘       └─┬─┘└───┘└───┘└─────┘└─┬─┘└───┘   »
# «ancilla_32 -> 35 ─┼───────────────────────┼─────────────────────┼──────────»
# «                  │                       │                     │          »
# «ancilla_33 -> 36 ─┼───────────────────────┼─────────────────────┼──────────»
# «                  │                       │                     │          »
# «ancilla_34 -> 37 ─┼───────────────────────┼─────────────────────┼──────────»
# «                  │                       │                     │          »
# «ancilla_35 -> 38 ─┼───────────────────────┼─────────────────────┼──────────»
# «                  │                       │                     │          »
# «ancilla_36 -> 39 ─┼───────────────────────┼─────────────────────┼──────────»
# «                  │ ┌───┐ ┌─────┐  ┌───┐  │                     │          »
# «       q_1 -> 40 ─┼─┤ X ├─┤ Tdg ├──┤ X ├──┼─────────────────────┼──────────»
# «                  │ └─┬─┘┌┴─────┴─┐└─┬─┘  │                     │          »
# «       q_4 -> 41 ─X───■──┤ P(π/2) ├──■────■─────────────────────■──────────»
# «                         └────────┘                                        »
# «ancilla_37 -> 42 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_38 -> 43 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_39 -> 44 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_40 -> 45 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_41 -> 46 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_42 -> 47 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_43 -> 48 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_44 -> 49 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_45 -> 50 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_46 -> 51 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_47 -> 52 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_48 -> 53 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_49 -> 54 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_50 -> 55 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_51 -> 56 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_52 -> 57 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_53 -> 58 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_54 -> 59 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_55 -> 60 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_56 -> 61 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_57 -> 62 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_58 -> 63 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_59 -> 64 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_60 -> 65 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_61 -> 66 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_62 -> 67 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_63 -> 68 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_64 -> 69 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_65 -> 70 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_66 -> 71 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_67 -> 72 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_68 -> 73 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_69 -> 74 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_70 -> 75 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_71 -> 76 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_72 -> 77 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_73 -> 78 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_74 -> 79 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_75 -> 80 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «ancilla_76 -> 81 ──────────────────────────────────────────────────────────»
# «                                                                           »
# «            c: 5/══════════════════════════════════════════════════════════»
# «                                                                           »
# «                                                                            »
# «  ancilla_0 -> 0 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «  ancilla_1 -> 1 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «  ancilla_2 -> 2 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «  ancilla_3 -> 3 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «  ancilla_4 -> 4 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «  ancilla_5 -> 5 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «  ancilla_6 -> 6 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «  ancilla_7 -> 7 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «  ancilla_8 -> 8 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «  ancilla_9 -> 9 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_10 -> 10 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_11 -> 11 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_12 -> 12 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_13 -> 13 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_14 -> 14 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_15 -> 15 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_16 -> 16 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_17 -> 17 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_18 -> 18 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_19 -> 19 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_20 -> 20 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_21 -> 21 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_22 -> 22 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_23 -> 23 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_24 -> 24 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_25 -> 25 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_26 -> 26 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_27 -> 27 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_28 -> 28 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_29 -> 29 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_30 -> 30 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_31 -> 31 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «       q_2 -> 32 ───────────────────────────────────────────────────────────»
# «                                  ┌───┐┌─────┐┌───┐┌───┐┌───┐┌─────┐   ┌───┐»
# «       q_3 -> 33 ─────────────────┤ X ├┤ Tdg ├┤ X ├┤ T ├┤ X ├┤ Tdg ├───┤ X ├»
# «                 ┌───┐┌─────┐┌───┐└─┬─┘└─────┘└─┬─┘└───┘└─┬─┘└┬───┬┘   └─┬─┘»
# «       q_0 -> 34 ┤ X ├┤ Tdg ├┤ X ├──■───────────┼─────────■───┤ T ├──X───┼──»
# «                 └─┬─┘└─────┘└─┬─┘              │             └───┘  │   │  »
# «ancilla_32 -> 35 ──┼───────────┼────────────────┼────────────────────┼───┼──»
# «                   │           │                │                    │   │  »
# «ancilla_33 -> 36 ──┼───────────┼────────────────┼────────────────────┼───┼──»
# «                   │           │                │                    │   │  »
# «ancilla_34 -> 37 ──┼───────────┼────────────────┼────────────────────┼───┼──»
# «                   │           │                │                    │   │  »
# «ancilla_35 -> 38 ──┼───────────┼────────────────┼────────────────────┼───┼──»
# «                   │           │                │                    │   │  »
# «ancilla_36 -> 39 ──┼───────────┼────────────────┼────────────────────┼───┼──»
# «                   │           │                │                    │   │  »
# «       q_1 -> 40 ──┼───────────┼────────────────■────────────────────┼───■──»
# «                   │           │                                     │      »
# «       q_4 -> 41 ──■───────────■─────────────────────────────────────X──────»
# «                                                                            »
# «ancilla_37 -> 42 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_38 -> 43 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_39 -> 44 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_40 -> 45 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_41 -> 46 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_42 -> 47 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_43 -> 48 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_44 -> 49 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_45 -> 50 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_46 -> 51 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_47 -> 52 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_48 -> 53 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_49 -> 54 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_50 -> 55 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_51 -> 56 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_52 -> 57 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_53 -> 58 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_54 -> 59 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_55 -> 60 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_56 -> 61 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_57 -> 62 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_58 -> 63 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_59 -> 64 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_60 -> 65 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_61 -> 66 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_62 -> 67 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_63 -> 68 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_64 -> 69 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_65 -> 70 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_66 -> 71 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_67 -> 72 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_68 -> 73 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_69 -> 74 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_70 -> 75 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_71 -> 76 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_72 -> 77 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_73 -> 78 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_74 -> 79 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_75 -> 80 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «ancilla_76 -> 81 ───────────────────────────────────────────────────────────»
# «                                                                            »
# «            c: 5/═══════════════════════════════════════════════════════════»
# «                                                                            »
# «
# «  ancilla_0 -> 0 ───────────────────────────────────
# «
# «  ancilla_1 -> 1 ───────────────────────────────────
# «
# «  ancilla_2 -> 2 ───────────────────────────────────
# «
# «  ancilla_3 -> 3 ───────────────────────────────────
# «
# «  ancilla_4 -> 4 ───────────────────────────────────
# «
# «  ancilla_5 -> 5 ───────────────────────────────────
# «
# «  ancilla_6 -> 6 ───────────────────────────────────
# «
# «  ancilla_7 -> 7 ───────────────────────────────────
# «
# «  ancilla_8 -> 8 ───────────────────────────────────
# «
# «  ancilla_9 -> 9 ───────────────────────────────────
# «
# «ancilla_10 -> 10 ───────────────────────────────────
# «
# «ancilla_11 -> 11 ───────────────────────────────────
# «
# «ancilla_12 -> 12 ───────────────────────────────────
# «
# «ancilla_13 -> 13 ───────────────────────────────────
# «
# «ancilla_14 -> 14 ───────────────────────────────────
# «
# «ancilla_15 -> 15 ───────────────────────────────────
# «
# «ancilla_16 -> 16 ───────────────────────────────────
# «
# «ancilla_17 -> 17 ───────────────────────────────────
# «
# «ancilla_18 -> 18 ───────────────────────────────────
# «
# «ancilla_19 -> 19 ───────────────────────────────────
# «
# «ancilla_20 -> 20 ───────────────────────────────────
# «
# «ancilla_21 -> 21 ───────────────────────────────────
# «
# «ancilla_22 -> 22 ───────────────────────────────────
# «
# «ancilla_23 -> 23 ───────────────────────────────────
# «
# «ancilla_24 -> 24 ───────────────────────────────────
# «
# «ancilla_25 -> 25 ───────────────────────────────────
# «
# «ancilla_26 -> 26 ───────────────────────────────────
# «
# «ancilla_27 -> 27 ───────────────────────────────────
# «
# «ancilla_28 -> 28 ───────────────────────────────────
# «
# «ancilla_29 -> 29 ───────────────────────────────────
# «
# «ancilla_30 -> 30 ───────────────────────────────────
# «
# «ancilla_31 -> 31 ───────────────────────────────────
# «                                   ░    ┌─┐
# «       q_2 -> 32 ──────────────────░────┤M├─────────
# «                 ┌───┐ ┌───┐       ░ ┌─┐└╥┘
# «       q_3 -> 33 ┤ T ├─┤ H ├───────░─┤M├─╫──────────
# «                 └───┘ └───┘       ░ └╥┘ ║       ┌─┐
# «       q_0 -> 34 ──────────────────░──╫──╫───────┤M├
# «                                   ░  ║  ║       └╥┘
# «ancilla_32 -> 35 ─────────────────────╫──╫────────╫─
# «                                      ║  ║        ║
# «ancilla_33 -> 36 ─────────────────────╫──╫────────╫─
# «                                      ║  ║        ║
# «ancilla_34 -> 37 ─────────────────────╫──╫────────╫─
# «                                      ║  ║        ║
# «ancilla_35 -> 38 ─────────────────────╫──╫────────╫─
# «                                      ║  ║        ║
# «ancilla_36 -> 39 ─────────────────────╫──╫────────╫─
# «                       ┌───┐       ░  ║  ║    ┌─┐ ║
# «       q_1 -> 40 ──■───┤ T ├───■───░──╫──╫────┤M├─╫─
# «                 ┌─┴─┐┌┴───┴┐┌─┴─┐ ░  ║  ║ ┌─┐└╥┘ ║
# «       q_4 -> 41 ┤ X ├┤ Tdg ├┤ X ├─░──╫──╫─┤M├─╫──╫─
# «                 └───┘└─────┘└───┘ ░  ║  ║ └╥┘ ║  ║
# «ancilla_37 -> 42 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_38 -> 43 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_39 -> 44 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_40 -> 45 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_41 -> 46 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_42 -> 47 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_43 -> 48 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_44 -> 49 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_45 -> 50 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_46 -> 51 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_47 -> 52 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_48 -> 53 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_49 -> 54 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_50 -> 55 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_51 -> 56 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_52 -> 57 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_53 -> 58 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_54 -> 59 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_55 -> 60 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_56 -> 61 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_57 -> 62 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_58 -> 63 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_59 -> 64 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_60 -> 65 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_61 -> 66 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_62 -> 67 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_63 -> 68 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_64 -> 69 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_65 -> 70 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_66 -> 71 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_67 -> 72 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_68 -> 73 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_69 -> 74 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_70 -> 75 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_71 -> 76 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_72 -> 77 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_73 -> 78 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_74 -> 79 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_75 -> 80 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «ancilla_76 -> 81 ─────────────────────╫──╫──╫──╫──╫─
# «                                      ║  ║  ║  ║  ║
# «            c: 5/═════════════════════╩══╩══╩══╩══╩═
# «                                      0  1  2  3  4

# %%
from qiskit.providers.jobstatus import JobStatus
import time

job = backend.run(trans_qc, shots=1024)

print("Job ID is", job.job_id(),"\n")

# 제출된 잡에 대한 지속적인 실행 상태 확인
#while job.status() is not JobStatus.DONE:
#	print("Job status is", job.status() )
#	time.sleep(2)
###while
# Out:
# Job ID is arn:aws:braket:us-west-1:013364996211:quantum-task/f7739a20-9350-4807-944c-9a1716f2f043

# %%
print("Job status is", job.status() )
# Out:
# Job status is JobStatus.DONE

# %%
# 중간에 세션이 종료된 경우 기존에 실행이 완료된 Job을 복구하는 방법
#job = backend.retrieve_job("arn:aws:braket:us-east-1:746669231099:quantum-task/f6fab6be-1590-4da0-914a-fade74efc485")

# %%
result = job.result()
result
# Out:
# Result(backend_name='Ankaa-3', backend_version='2', qobj_id='0', job_id='arn:aws:braket:us-west-1:013364996211:quantum-task/f7739a20-9350-4807-944c-9a1716f2f043', success=True, results=[ExperimentResult(shots=1024, success=True, meas_level=2, data=ExperimentResultData(counts={'11001': 225, '01001': 58, '10001': 125, '10010': 10, '01101': 12, '10100': 31, '10101': 55, '10000': 68, '01010': 6, '01000': 33, '11000': 107, '00010': 7, '00000': 21, '11100': 42, '11101': 69, '11111': 13, '00001': 32, '10011': 9, '00101': 10, '00100': 16, '11010': 6, '10110': 10, '00011': 6, '11011': 15, '01111': 3, '10111': 6, '01100': 9, '01011': 11, '01110': 2, '00111': 3, '00110': 2, '11110': 2}, memory=['11001', '01001', '10001', '10010', '01101', '10100', '11001', '10101', '11001', '11001', '10000', '11001', '01010', '11001', '10000', '01000', '11000', '00010', '00000', '11000', '01101', '11001', '10001', '11000', '10001', '11100', '11001', '11000', '11001', '01001', '11000', '11101', '10001', '10001', '10101', '10000', '10000', '10000', '10000', '11101', '11111', '00001', '11000', '11000', '10001', '10000', '11101', '10001', '10100', '01001', '11000', '11100', '10011', '00000', '10100', '10101', '10001', '11000', '10001', '00101', '00001', '10001', '10001', '11001', '10001', '11001', '10001', '00000', '00101', '00001', '11000', '10101', '11001', '11001', '00100', '10001', '11010', '10001', '11001', '11000', '00100', '10001', '11001', '01001', '00100', '01001', '10100', '10100', '01000', '11111', '10100', '11001', '10011', '11101', '11101', '10110', '10101', '00011', '01001', '11101', '11001', '11100', '01010', '10001', '11011', '10001', '01000', '11001', '00000', '11000', '10000', '11001', '11001', '11001', '11001', '11001', '11001', '11000', '11101', '11001', '11011', '01101', '10100', '10101', '11000', '11101', '11001', '10101', '01111', '11000', '10100', '01000', '11011', '11001', '11011', '11000', '00001', '10001', '10100', '10001', '01001', '11000', '11000', '11001', '11001', '10101', '11001', '11000', '10000', '11001', '11101', '11000', '00000', '11100', '11001', '01001', '10101', '11001', '11101', '01001', '11100', '11001', '11001', '01000', '11001', '11001', '11001', '00000', '10001', '11001', '11101', '01000', '11011', '10001', '10001', '01001', '11000', '01000', '10111', '10001', '11000', '11100', '11001', '01000', '01001', '11000', '10001', '10000', '01001', '10001', '11001', '10101', '11101', '10100', '11000', '10001', '11001', '11101', '01001', '11001', '11011', '11000', '01000', '11001', '10111', '01001', '00101', '01001', '00001', '11001', '01001', '11001', '11001', '11000', '10100', '11001', '01000', '11000', '11001', '10101', '10001', '11001', '11100', '11001', '01000', '10000', '11001', '11001', '10001', '10000', '01100', '11000', '01101', '00001', '10101', '11101', '11001', '10001', '00101', '10001', '11001', '01001', '01101', '11001', '01001', '10101', '11001', '01000', '11101', '00001', '11010', '01011', '11000', '11101', '00001', '10000', '11001', '11001', '00010', '00101', '10001', '11001', '11011', '11000', '00001', '10000', '10111', '10110', '01001', '10000', '11001', '10001', '00101', '10000', '11001', '11101', '11000', '11001', '10000', '01001', '10001', '11001', '10101', '10101', '11000', '10101', '10100', '00010', '11111', '01001', '10100', '11101', '11101', '01011', '10001', '10101', '11101', '00010', '11001', '10001', '10001', '11100', '00000', '11101', '10000', '11100', '11001', '10001', '10001', '10101', '11001', '11001', '10101', '11001', '11100', '00001', '11000', '00001', '10010', '10100', '00100', '10110', '10000', '10001', '10000', '00000', '10101', '11001', '11001', '10101', '11111', '00001', '10010', '00100', '01011', '11100', '11001', '11100', '11001', '11000', '11101', '10111', '10000', '11000', '11001', '11001', '11101', '01101', '10101', '11100', '10101', '10100', '10101', '11101', '10111', '01000', '11001', '10100', '11001', '11001', '10000', '11001', '10001', '01001', '01110', '11100', '11001', '010 ...

# %%
# 결과 출력
counts = result.get_counts()
print(counts)
# Out:
# {'11001': 225, '01001': 58, '10001': 125, '10010': 10, '01101': 12, '10100': 31, '10101': 55, '10000': 68, '01010': 6, '01000': 33, '11000': 107, '00010': 7, '00000': 21, '11100': 42, '11101': 69, '11111': 13, '00001': 32, '10011': 9, '00101': 10, '00100': 16, '11010': 6, '10110': 10, '00011': 6, '11011': 15, '01111': 3, '10111': 6, '01100': 9, '01011': 11, '01110': 2, '00111': 3, '00110': 2, '11110': 2}

# %%
from qiskit.visualization import plot_histogram
plot_histogram(data=counts)

# %%
print("Quantum Task Summary\n")
print(t.quantum_tasks_statistics())
print('\nNote: Charges shown are estimates based on your Amazon Braket simulator and quantum processing unit (QPU) task usage. \nEstimated charges shown may differ from your actual charges. \nEstimated charges do not factor in any discounts or credits, \nand you may experience additional charges based on your use of other services such as Amazon Elastic Compute Cloud (Amazon EC2).')
print(f"\nEstimated cost to run this example: {t.qpu_tasks_cost() + t.simulator_tasks_cost():.2f} USD")
# Out:
# Quantum Task Summary
#
# {'arn:aws:braket:::device/quantum-simulator/amazon/sv1': {'shots': 1024, 'tasks': {'COMPLETED': 1}, 'execution_duration': datetime.timedelta(microseconds=4000), 'billed_execution_duration': datetime.timedelta(seconds=3)}, 'arn:aws:braket:us-west-1::device/qpu/rigetti/Ankaa-3': {'shots': 1024, 'tasks': {'COMPLETED': 1}}}
#
# Note: Charges shown are estimates based on your Amazon Braket simulator and quantum processing unit (QPU) task usage.
# Estimated charges shown may differ from your actual charges.
# Estimated charges do not factor in any discounts or credits,
# and you may experience additional charges based on your use of other services such as Amazon Elastic Compute Cloud (Amazon EC2).
#
# Estimated cost to run this example: 1.23 USD
