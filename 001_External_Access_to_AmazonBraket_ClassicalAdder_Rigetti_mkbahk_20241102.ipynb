# %% [markdown]
# # 작업순서
# 1. Amazon Braket 환경 설정(확인만)
# 2. S3 환경설정(확인만)
# 3. (중요) IAM을 이용한 Access Key 설정 및 권한 부여
# 4. 원격 작업
# 5. 각종 로그 보기
# 6. 작업 환경 정리

# %%
#!pip install git+https://github.com/qiskit-community/qiskit-braket-provider.git

# %%
# !pip install qiskit-braket-provider==0.7.0
# !pip install amazon-braket-sdk==1.108.1
#!pip install amazon-braket-sdk==1.94.0
#!python3 -m pip install boto3
#!python3 -m pip install botocore
# Out:
# Requirement already satisfied: qiskit-braket-provider==0.7.0 in /usr/local/lib/python3.12/dist-packages (0.7.0)
# Requirement already satisfied: certifi>=2021.5.30 in /usr/local/lib/python3.12/dist-packages (from qiskit-braket-provider==0.7.0) (2026.1.4)
# Requirement already satisfied: qiskit>=0.34.2 in /usr/local/lib/python3.12/dist-packages (from qiskit-braket-provider==0.7.0) (2.3.0)
# Requirement already satisfied: qiskit-ionq>=0.5.2 in /usr/local/lib/python3.12/dist-packages (from qiskit-braket-provider==0.7.0) (1.0.2)
# Requirement already satisfied: amazon-braket-sdk>=1.99.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-braket-provider==0.7.0) (1.104.1)
# Requirement already satisfied: setuptools>=40.1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-braket-provider==0.7.0) (75.2.0)
# Requirement already satisfied: numpy>=1.3 in /usr/local/lib/python3.12/dist-packages (from qiskit-braket-provider==0.7.0) (2.0.2)
# Requirement already satisfied: amazon-braket-schemas>=1.26.1 in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (1.27.0)
# Requirement already satisfied: amazon-braket-default-simulator>=1.32.0 in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (1.32.1)
# Requirement already satisfied: oqpy~=0.3.7 in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (0.3.9)
# Requirement already satisfied: backoff in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (2.2.1)
# Requirement already satisfied: boltons in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (25.0.0)
# Requirement already satisfied: boto3>=1.28.53 in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (1.42.26)
# Requirement already satisfied: cloudpickle==2.2.1 in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (2.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (1.6.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (3.6.1)
# Requirement already satisfied: openpulse in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (1.0.1)
# Requirement already satisfied: openqasm3 in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (1.0.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (1.14.0)
# Requirement already satisfied: backports.entry-points-selectable in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (1.3.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.34.2->qiskit-braket-provider==0.7.0) (0.17.1)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.34.2->qiskit-braket-provider==0.7.0) (1.16.3)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.34.2->qiskit-braket-provider==0.7.0) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.34.2->qiskit-braket-provider==0.7.0) (5.6.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.34.2->qiskit-braket-provider==0.7.0) (4.15.0)
# Requirement already satisfied: decorator>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-ionq>=0.5.2->qiskit-braket-provider==0.7.0) (5.2.1)
# Requirement already satisfied: requests>=2.24.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-ionq>=0.5.2->qiskit-braket-provider==0.7.0) (2.32.4)
# Requirement already satisfied: importlib-metadata>=4.11.4 in /usr/local/lib/python3.12/dist-packages (from qiskit-ionq>=0.5.2->qiskit-braket-provider==0.7.0) (8.7.1)
# Requirement already satisfied: python-dotenv>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from qiskit-ionq>=0.5.2->qiskit-braket-provider==0.7.0) (1.2.1)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (0.60.0)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.12/dist-packages (from amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (3.4.0)
# Requirement already satisfied: pydantic>2 in /usr/local/lib/python3.12/dist-packages (from amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (2.12.3)
# Requirement already satisfied: antlr4-python3-runtime==4.13.2 in /usr/local/lib/python3.12/dist-packages (from amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (4.13.2)
# Requirement already satisfied: botocore<1.43.0,>=1.42.26 in /usr/local/lib/python3.12/dist-packages (from boto3>=1.28.53->amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (1.42.26)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from boto3>=1.28.53->amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (1.0.1)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /usr/local/lib/python3.12/dist-packages (from boto3>=1.28.53->amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata>=4.11.4->qiskit-ionq>=0.5.2->qiskit-braket-provider==0.7.0) (3.23.0)
# Requirement already satisfied: mypy-extensions>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from oqpy~=0.3.7->amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (1.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.24.0->qiskit-ionq>=0.5.2->qiskit-braket-provider==0.7.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.24.0->qiskit-ionq>=0.5.2->qiskit-braket-provider==0.7.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.24.0->qiskit-ionq>=0.5.2->qiskit-braket-provider==0.7.0) (2.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (1.3.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from botocore<1.43.0,>=1.42.26->boto3>=1.28.53->amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (2.9.0.post0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>2->amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>2->amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>2->amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (0.4.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.43.0,>=1.42.26->boto3>=1.28.53->amazon-braket-sdk>=1.99.0->qiskit-braket-provider==0.7.0) (1.17.0)
# Collecting amazon-braket-sdk==1.108.1
#   Using cached amazon_braket_sdk-1.108.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: amazon-braket-schemas>=1.27.0 in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk==1.108.1) (1.27.0)
# Requirement already satisfied: amazon-braket-default-simulator>=1.32.0 in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk==1.108.1) (1.32.1)
# Requirement already satisfied: oqpy~=0.3.7 in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk==1.108.1) (0.3.9)
# Requirement already satisfied: backoff in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk==1.108.1) (2.2.1)
# Requirement already satisfied: boltons in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk==1.108.1) (25.0.0)
# Requirement already satisfied: boto3>=1.28.53 in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk==1.108.1) (1.42.26)
# Requirement already satisfied: cloudpickle==2.2.1 in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk==1.108.1) (2.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk==1.108.1) (1.6.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk==1.108.1) (3.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk==1.108.1) (2.0.2)
# Requirement already satisfied: openpulse in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk==1.108.1) (1.0.1)
# Requirement already satisfied: openqasm3 in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk==1.108.1) (1.0.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk==1.108.1) (1.14.0)
# Requirement already satisfied: backports.entry-points-selectable in /usr/local/lib/python3.12/dist-packages (from amazon-braket-sdk==1.108.1) (1.3.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk==1.108.1) (0.60.0)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.12/dist-packages (from amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk==1.108.1) (3.4.0)
# Requirement already satisfied: pydantic>2 in /usr/local/lib/python3.12/dist-packages (from amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk==1.108.1) (2.12.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk==1.108.1) (1.16.3)
# Requirement already satisfied: antlr4-python3-runtime==4.13.2 in /usr/local/lib/python3.12/dist-packages (from amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk==1.108.1) (4.13.2)
# Requirement already satisfied: botocore<1.43.0,>=1.42.26 in /usr/local/lib/python3.12/dist-packages (from boto3>=1.28.53->amazon-braket-sdk==1.108.1) (1.42.26)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from boto3>=1.28.53->amazon-braket-sdk==1.108.1) (1.0.1)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /usr/local/lib/python3.12/dist-packages (from boto3>=1.28.53->amazon-braket-sdk==1.108.1) (0.16.0)
# Requirement already satisfied: mypy-extensions>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from oqpy~=0.3.7->amazon-braket-sdk==1.108.1) (1.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->amazon-braket-sdk==1.108.1) (1.3.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from botocore<1.43.0,>=1.42.26->boto3>=1.28.53->amazon-braket-sdk==1.108.1) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.12/dist-packages (from botocore<1.43.0,>=1.42.26->boto3>=1.28.53->amazon-braket-sdk==1.108.1) (2.5.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>2->amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk==1.108.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>2->amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk==1.108.1) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic>2->amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk==1.108.1) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>2->amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk==1.108.1) (0.4.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->amazon-braket-default-simulator>=1.32.0->amazon-braket-sdk==1.108.1) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.43.0,>=1.42.26->boto3>=1.28.53->amazon-braket-sdk==1.108.1) (1.17.0)
# Using cached amazon_braket_sdk-1.108.1-py3-none-any.whl (373 kB)
# Installing collected packages: amazon-braket-sdk
#   Attempting uninstall: amazon-braket-sdk
#     Found existing installation: amazon-braket-sdk 1.104.1
#     Uninstalling amazon-braket-sdk-1.104.1:
#       Successfully uninstalled amazon-braket-sdk-1.104.1
# Successfully installed amazon-braket-sdk-1.108.1

# %%
# %pip show qiskit
# %pip show qiskit-braket-provider
# %pip show amazon-braket-sdk
# Out:
# Name: qiskit
# Version: 2.3.0
# Summary: An open-source SDK for working with quantum computers at the level of extended quantum circuits, operators, and primitives.
# Home-page: https://www.ibm.com/quantum/qiskit
# Author:
# Author-email: Qiskit Development Team <qiskit@us.ibm.com>
# License:
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: dill, numpy, rustworkx, scipy, stevedore, typing-extensions
# Required-by: qiskit-ionq, qiskit_braket_provider
# Name: qiskit_braket_provider
# Version: 0.7.0
# Summary: Qiskit-Braket provider to execute Qiskit programs on AWS quantum computing hardware devices through Amazon Braket.
# Home-page:
# Author:
# Author-email:
# License:
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: amazon-braket-sdk, certifi, numpy, qiskit, qiskit-ionq, setuptools
# Required-by:
# Name: amazon-braket-sdk
# Version: 1.108.1
# Summary: An open source library for interacting with quantum computing devices on Amazon Braket
# Home-page: https://github.com/amazon-braket/amazon-braket-sdk-python
# Author: Amazon Web Services
# Author-email:
# License: Apache License 2.0
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: amazon-braket-default-simulator, amazon-braket-schemas, backoff, backports.entry-points-selectable, boltons, boto3, cloudpickle, nest-asyncio, networkx, numpy, openpulse, openqasm3, oqpy, sympy
# Required-by: qiskit_braket_provider

# %%
from braket.experimental_capabilities import EnableExperimentalCapability

# %%
import warnings

# warnings 모듈을 사용하여 특정 경고 메시지를 무시합니다.
warnings.filterwarnings('ignore')

# %%
# Use Braket SDK Cost Tracking to estimate the cost to run this example
from braket.tracking import Tracker
t = Tracker().start()

# %%
import os
# Set environment variables for AWS credentials
os.environ['AWS_ACCESS_KEY_ID'] = ""
os.environ['AWS_SECRET_ACCESS_KEY'] = ""
os.environ['AWS_DEFAULT_REGION'] = "us-east-1"

# You can optionally set the s3 bucket and prefix using environment variables
#os.environ['AWS_BRAKET_S3_BUCKET'] = "snuqc"
#os.environ['AWS_BRAKET_S3_PREFIX'] = "amazonbraket"

# %%
from qiskit_braket_provider import BraketLocalBackend

local_simulator = BraketLocalBackend()
#local_sv_simulator = BraketLocalBackend(name='braket_sv')
#local_dm_simulator = BraketLocalBackend(name='braket_dm')

# %%
from qiskit_braket_provider import BraketProvider

provider = BraketProvider()
#provider.backends(statuses=["ONLINE"], types=["SIMULATOR"])
#provider.backends(statuses=["ONLINE"], types=["QPU"])
provider.backends(statuses=["ONLINE"], types=["SIMULATOR", "QPU"])
# Out:
# [BraketBackend[Ankaa-3],
#  BraketBackend[Emerald],
#  BraketBackend[Forte 1],
#  BraketBackend[Garnet],
#  BraketBackend[SV1],
#  BraketBackend[TN1],
#  BraketBackend[dm1]]

# %%
#backend = provider.get_backend("Aria 1")
#backend = provider.get_backend("Aria 2")
#backend = provider.get_backend("Forte 1")

backend= provider.get_backend("Ankaa-3")
#backend = provider.get_backend("Aspen-M-3")

#backend = provider.get_backend("Garnet")

#backend = provider.get_backend("SV1")
#backend = provider.get_backend("dm1")
#backend = provider.get_backend("TN1")

# %%
from qiskit import QuantumCircuit

# 양자 회로 생성
circuit = QuantumCircuit(5, 5)  # 5개의 양자 비트와 2개의 클래식 비트를 사용합니다.

# 입력 비트 설정 (A=1, B=1)
circuit.x(0)  # A 비트를 1로 설정
circuit.x(1)  # B 비트를 1로 설정
circuit.barrier()

# 반-가산기 회로 구현
circuit.cx(0, 3) # XOR 게이트 (A와 B의 논리합)
circuit.cx(1, 3) # XOR 게이트 (A와 B의 논리합)
circuit.ccx(0, 1, 4) # AND 게이트 (A와 B의 논리곱)
circuit.cx(2, 3) # XOR 게이트 (A와 B의 논리합)
circuit.ccx(0, 2, 4) # AND 게이트 (A와 B의 논리곱)
circuit.ccx(1, 2, 4) # AND 게이트 (A와 B의 논리곱)
circuit.barrier()

# 결과를 측정하여 Sum과 Carry 출력을 얻습니다.
circuit.measure(0, 4)  # 큐비트를 클래식 비트 4에 매핑
circuit.measure(1, 3)  # 큐비트를 클래식 비트 3에 매핑
circuit.measure(2, 2)  # 보조비트를 클래식 비트 2에 매핑
circuit.measure(3, 1)  # Sum(Result) 비트를 클래식 비트 1에 매핑
circuit.measure(4, 0)  # Carry 비트를 클래식 비트 0에 매핑

# %%
circuit.draw()
# Out:
#      ┌───┐ ░                                ░ ┌─┐
# q_0: ┤ X ├─░───■─────────■─────────■────────░─┤M├────────────
#      ├───┤ ░   │         │         │        ░ └╥┘┌─┐
# q_1: ┤ X ├─░───┼────■────■─────────┼────■───░──╫─┤M├─────────
#      └───┘ ░   │    │    │         │    │   ░  ║ └╥┘┌─┐
# q_2: ──────░───┼────┼────┼────■────■────■───░──╫──╫─┤M├──────
#            ░ ┌─┴─┐┌─┴─┐  │  ┌─┴─┐  │    │   ░  ║  ║ └╥┘┌─┐
# q_3: ──────░─┤ X ├┤ X ├──┼──┤ X ├──┼────┼───░──╫──╫──╫─┤M├───
#            ░ └───┘└───┘┌─┴─┐└───┘┌─┴─┐┌─┴─┐ ░  ║  ║  ║ └╥┘┌─┐
# q_4: ──────░───────────┤ X ├─────┤ X ├┤ X ├─░──╫──╫──╫──╫─┤M├
#            ░           └───┘     └───┘└───┘ ░  ║  ║  ║  ║ └╥┘
# c: 5/══════════════════════════════════════════╩══╩══╩══╩══╩═
#                                                4  3  2  1  0

# %%
from qiskit.compiler import transpile
trans_qc = transpile(circuit, backend)
trans_qc.draw()
# Out:
# global phase: 9π/8
#          ┌───────┐ ░   ┌──────────┐                                   »
# q_1 -> 0 ┤ Rx(π) ├─░───┤ Rx(-π/2) ├───────────────────────────────────»
#          └───────┘ ░ ┌─┴──────────┴┐┌──────────┐┌────────┐┌─────────┐ »
# q_3 -> 1 ──────────░─┤ Rx(-1.8841) ├┤ Rz(-π/2) ├┤0       ├┤ Rz(π/2) ├─»
#                    ░ └┬────────────┤└──────────┘│        │└─────────┘ »
# q_2 -> 2 ──────────░──┤ Rz(1.8438) ├────────────┤        ├────────────»
#                    ░  └┬──────────┬┘            │  Iswap │            »
# q_4 -> 7 ──────────░───┤ Rz(-π/2) ├─────────────┤        ├────────────»
#          ┌───────┐ ░   ├─────────┬┘  ┌───────┐  │        │┌──────────┐»
# q_0 -> 8 ┤ Rx(π) ├─░───┤ Rz(π/2) ├───┤ Rx(π) ├──┤1       ├┤ Rx(-π/2) ├»
#          └───────┘ ░   └─────────┘   └───────┘  └────────┘└──────────┘»
#     c: 5/═════════════════════════════════════════════════════════════»
#                                                                       »
# «                                                                        »
# «q_1 -> 0 ───────────────────────────────────────────────────────────────»
# «          ┌───────┐ ┌────────┐  ┌─────────┐   ┌─────────┐┌─────────────┐»
# «q_3 -> 1 ─┤ Rx(π) ├─┤0       ├──┤ Rz(π/2) ├───┤ Rx(π/2) ├┤ Rz(-2.8283) ├»
# «          └───────┘ │        │  └─────────┘   └─────────┘└─────────────┘»
# «q_2 -> 2 ───────────┤        ├──────────────────────────────────────────»
# «                    │  Iswap │                                          »
# «q_4 -> 7 ───────────┤        ├──────────────────────────────────────────»
# «         ┌─────────┐│        │┌──────────────┐┌─────────┐               »
# «q_0 -> 8 ┤ Rz(π/2) ├┤1       ├┤ Rz(-0.18498) ├┤ Rx(π/2) ├───────────────»
# «         └─────────┘└────────┘└──────────────┘└─────────┘               »
# «    c: 5/═══════════════════════════════════════════════════════════════»
# «                                                                        »
# «         ┌────────┐┌─────────┐  ┌───────┐ ┌────────┐┌─────────────┐»
# «q_1 -> 0 ┤0       ├┤ Rz(π/2) ├──┤ Rx(π) ├─┤0       ├┤ Rx(-1.8694) ├»
# «         │  Iswap │├─────────┴┐┌┴───────┴┐│  Iswap │├─────────────┤»
# «q_3 -> 1 ┤1       ├┤ Rx(-π/2) ├┤ Rz(π/2) ├┤1       ├┤ Rz(-1.2978) ├»
# «         └────────┘└──────────┘└─────────┘└────────┘└─────────────┘»
# «q_2 -> 2 ──────────────────────────────────────────────────────────»
# «                                                                   »
# «q_4 -> 7 ──────────────────────────────────────────────────────────»
# «                                                                   »
# «q_0 -> 8 ──────────────────────────────────────────────────────────»
# «                                                                   »
# «    c: 5/══════════════════════════════════════════════════════════»
# «                                                                   »
# «         ┌──────────┐┌────────┐┌─────────┐    ┌───────┐               »
# «q_1 -> 0 ┤ Rz(-π/2) ├┤0       ├┤ Rz(π/2) ├────┤ Rx(π) ├───────────────»
# «         └┬───────┬─┘│        │└┬────────┤  ┌─┴───────┴──┐┌──────────┐»
# «q_3 -> 1 ─┤ Rx(π) ├──┤        ├─┤0       ├──┤ Rz(-2.625) ├┤ Rx(-π/2) ├»
# «          └───────┘  │  Iswap │ │  Iswap │ ┌┴────────────┤├─────────┬┘»
# «q_2 -> 2 ────────────┤        ├─┤1       ├─┤ Rz(0.27303) ├┤ Rx(π/2) ├─»
# «                     │        │┌┴────────┴┐└─┬─────────┬─┘└─────────┘ »
# «q_4 -> 7 ────────────┤1       ├┤ Rx(-π/2) ├──┤ Rz(π/2) ├──────────────»
# «                     └────────┘└──────────┘  └─────────┘              »
# «q_0 -> 8 ─────────────────────────────────────────────────────────────»
# «                                                                      »
# «    c: 5/═════════════════════════════════════════════════════════════»
# «                                                                      »
# «                    ┌────────┐┌────────────┐┌──────────┐                      »
# «q_1 -> 0 ───────────┤0       ├┤ Rx(1.4475) ├┤ Rz(-π/2) ├──────────────────────»
# «                    │        │└────────────┘└──────────┘                      »
# «q_3 -> 1 ───────────┤        ├────────────────────────────────────────────────»
# «         ┌─────────┐│  Iswap │                                                »
# «q_2 -> 2 ┤ Rz(π/2) ├┤        ├────────────────────────────────────────────────»
# «         └─────────┘│        │ ┌──────────┐ ┌─────────┐ ┌──────────┐┌────────┐»
# «q_4 -> 7 ───────────┤1       ├─┤ Rz(-π/2) ├─┤ Rx(π/4) ├─┤ Rz(-π/2) ├┤1       ├»
# «                    └────────┘ └──────────┘ └─────────┘ └──────────┘│  Iswap │»
# «q_0 -> 8 ───────────────────────────────────────────────────────────┤0       ├»
# «                                                                    └────────┘»
# «    c: 5/═════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «                                                                  »
# «q_1 -> 0 ─────────────────────────────────────────────────────────»
# «                                                                  »
# «q_3 -> 1 ─────────────────────────────────────────────────────────»
# «                                                                  »
# «q_2 -> 2 ─────────────────────────────────────────────────────────»
# «         ┌──────────┐┌─────────┐┌────────┐┌──────────┐┌──────────┐»
# «q_4 -> 7 ┤ Rx(-π/2) ├┤ Rz(π/2) ├┤1       ├┤ Rz(-π/2) ├┤ Rx(-π/4) ├»
# «         ├─────────┬┘└┬───────┬┘│  Iswap │├─────────┬┘├─────────┬┘»
# «q_0 -> 8 ┤ Rz(π/2) ├──┤ Rx(π) ├─┤0       ├┤ Rz(π/2) ├─┤ Rx(π/2) ├─»
# «         └─────────┘  └───────┘ └────────┘└─────────┘ └─────────┘ »
# «    c: 5/═════════════════════════════════════════════════════════»
# «                                                                  »
# «                        ┌────────┐┌─────────┐  ┌───────┐ ┌────────┐»
# «q_1 -> 0 ───────────────┤0       ├┤ Rz(π/2) ├──┤ Rx(π) ├─┤0       ├»
# «                        │        │└─────────┘  └───────┘ │        │»
# «q_3 -> 1 ───────────────┤        ├───────────────────────┤        ├»
# «                        │  Iswap │                       │  Iswap │»
# «q_2 -> 2 ───────────────┤        ├───────────────────────┤        ├»
# «           ┌──────────┐ │        │┌──────────┐┌─────────┐│        │»
# «q_4 -> 7 ──┤ Rz(-π/2) ├─┤1       ├┤ Rx(-π/2) ├┤ Rz(π/2) ├┤1       ├»
# «         ┌─┴──────────┴┐└────────┘└──────────┘└─────────┘└────────┘»
# «q_0 -> 8 ┤ Rz(-3.0346) ├───────────────────────────────────────────»
# «         └─────────────┘                                           »
# «    c: 5/══════════════════════════════════════════════════════════»
# «                                                                   »
# «         ┌─────────┐ ┌─────────┐ ┌──────────────┐                         »
# «q_1 -> 0 ┤ Rz(π/2) ├─┤ Rx(π/2) ├─┤ Rz(-0.18464) ├─────────────────────────»
# «         └─────────┘ └─────────┘ └──────────────┘                         »
# «q_3 -> 1 ─────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_2 -> 2 ─────────────────────────────────────────────────────────────────»
# «         ┌──────────┐┌──────────┐┌─────────────┐ ┌────────┐┌─────────────┐»
# «q_4 -> 7 ┤ Rz(-π/2) ├┤ Rx(3π/4) ├┤ Rz(-2.7087) ├─┤0       ├┤ Rz(0.84422) ├»
# «         └──────────┘└──────────┘└─────────────┘ │  Iswap │└┬────────────┤»
# «q_0 -> 8 ────────────────────────────────────────┤1       ├─┤ Rz(1.1379) ├»
# «                                                 └────────┘ └────────────┘»
# «    c: 5/═════════════════════════════════════════════════════════════════»
# «                                                                          »
# «                     ┌────────┐┌───────────┐┌─────────┐             ┌────────┐»
# «q_1 -> 0 ────────────┤1       ├┤ Rx(-3π/4) ├┤ Rz(π/2) ├─────────────┤1       ├»
# «                     │        │└───────────┘└┬────────┤┌─────────┐  │        │»
# «q_3 -> 1 ────────────┤        ├──────────────┤0       ├┤ Rz(π/2) ├──┤        ├»
# «                     │  Iswap │              │        │└─────────┘  │  Iswap │»
# «q_2 -> 2 ────────────┤        ├──────────────┤        ├─────────────┤        ├»
# «         ┌─────────┐ │        │ ┌─────────┐  │  Iswap │ ┌───────┐   │        │»
# «q_4 -> 7 ┤ Rx(π/2) ├─┤0       ├─┤ Rz(π/2) ├──┤        ├─┤ Rx(π) ├───┤0       ├»
# «         ├─────────┤┌┴────────┤ └─────────┘  │        │┌┴───────┴─┐┌┴────────┤»
# «q_0 -> 8 ┤ Rx(π/4) ├┤ Rz(π/2) ├──────────────┤1       ├┤ Rx(-π/2) ├┤ Rz(π/2) ├»
# «         └─────────┘└─────────┘              └────────┘└──────────┘└─────────┘»
# «    c: 5/═════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «         ┌─────────────┐ ┌─────────┐                                      »
# «q_1 -> 0 ┤ Rz(-1.5769) ├─┤ Rx(π/2) ├──────────────────────────────────────»
# «         └──┬───────┬──┘ └┬────────┤┌────────────┐┌──────────┐            »
# «q_3 -> 1 ───┤ Rx(π) ├─────┤0       ├┤ Rx(-1.203) ├┤ Rz(-π/2) ├────────────»
# «            └───────┘     │        │└────────────┘└──────────┘            »
# «q_2 -> 2 ─────────────────┤        ├──────────────────────────────────────»
# «         ┌──────────────┐ │  Iswap │ ┌──────────┐                         »
# «q_4 -> 7 ┤ Rx(-0.16585) ├─┤        ├─┤ Rz(-π/2) ├─────────────────────────»
# «         └──────────────┘ │        │ ├─────────┬┘ ┌─────────┐ ┌──────────┐»
# «q_0 -> 8 ─────────────────┤1       ├─┤ Rz(π/2) ├──┤ Rx(π/4) ├─┤ Rz(-π/2) ├»
# «                          └────────┘ └─────────┘  └─────────┘ └──────────┘»
# «    c: 5/═════════════════════════════════════════════════════════════════»
# «                                                                          »
# «                                                                   »
# «q_1 -> 0 ──────────────────────────────────────────────────────────»
# «                                                                   »
# «q_3 -> 1 ──────────────────────────────────────────────────────────»
# «                                                                   »
# «q_2 -> 2 ──────────────────────────────────────────────────────────»
# «         ┌────────┐┌─────────┐  ┌───────┐ ┌────────┐┌─────────────┐»
# «q_4 -> 7 ┤0       ├┤ Rz(π/2) ├──┤ Rx(π) ├─┤0       ├┤ Rx(-1.4638) ├»
# «         │  Iswap │├─────────┴┐┌┴───────┴┐│  Iswap │└─┬──────────┬┘»
# «q_0 -> 8 ┤1       ├┤ Rx(-π/2) ├┤ Rz(π/2) ├┤1       ├──┤ Rz(-π/2) ├─»
# «         └────────┘└──────────┘└─────────┘└────────┘  └──────────┘ »
# «    c: 5/══════════════════════════════════════════════════════════»
# «                                                                   »
# «                                                                            »
# «q_1 -> 0 ───────────────────────────────────────────────────────────────────»
# «                                 ┌────────┐┌─────────┐  ┌───────┐ ┌────────┐»
# «q_3 -> 1 ────────────────────────┤0       ├┤ Rz(π/2) ├──┤ Rx(π) ├─┤0       ├»
# «                                 │        │└─────────┘  └───────┘ │        │»
# «q_2 -> 2 ────────────────────────┤        ├───────────────────────┤        ├»
# «         ┌──────────┐            │  Iswap │                       │  Iswap │»
# «q_4 -> 7 ┤ Rz(-π/2) ├────────────┤        ├───────────────────────┤        ├»
# «         ├──────────┤┌──────────┐│        │┌──────────┐┌─────────┐│        │»
# «q_0 -> 8 ┤ Rx(-π/4) ├┤ Rz(-π/2) ├┤1       ├┤ Rx(-π/2) ├┤ Rz(π/2) ├┤1       ├»
# «         └──────────┘└──────────┘└────────┘└──────────┘└─────────┘└────────┘»
# «    c: 5/═══════════════════════════════════════════════════════════════════»
# «                                                                            »
# «                                                                     »
# «q_1 -> 0 ────────────────────────────────────────────────────────────»
# «          ┌────────┐┌─────────────┐                                  »
# «q_3 -> 1 ─┤ Rz(-π) ├┤ Rx(-1.2073) ├──────────────────────────────────»
# «          └────────┘└─────────────┘                                  »
# «q_2 -> 2 ────────────────────────────────────────────────────────────»
# «                                               ┌────────┐┌─────────┐ »
# «q_4 -> 7 ──────────────────────────────────────┤0       ├┤ Rz(π/2) ├─»
# «         ┌─────────┐  ┌─────────┐  ┌──────────┐│  Iswap │├─────────┴┐»
# «q_0 -> 8 ┤ Rz(π/2) ├──┤ Rx(π/4) ├──┤ Rz(-π/2) ├┤1       ├┤ Rx(-π/2) ├»
# «         └─────────┘  └─────────┘  └──────────┘└────────┘└──────────┘»
# «    c: 5/════════════════════════════════════════════════════════════»
# «                                                                     »
# «                                                                             »
# «q_1 -> 0 ────────────────────────────────────────────────────────────────────»
# «                                                                   ┌────────┐»
# «q_3 -> 1 ──────────────────────────────────────────────────────────┤0       ├»
# «                                                                   │        │»
# «q_2 -> 2 ──────────────────────────────────────────────────────────┤        ├»
# «          ┌───────┐ ┌────────┐┌────────────┐┌─────────┐            │  Iswap │»
# «q_4 -> 7 ─┤ Rx(π) ├─┤0       ├┤ Rx(0.1948) ├┤ Rz(π/2) ├────────────┤        ├»
# «         ┌┴───────┴┐│  Iswap │└┬──────────┬┘├─────────┴┐┌─────────┐│        │»
# «q_0 -> 8 ┤ Rz(π/2) ├┤1       ├─┤ Rz(-π/2) ├─┤ Rx(3π/4) ├┤ Rz(π/2) ├┤1       ├»
# «         └─────────┘└────────┘ └──────────┘ └──────────┘└─────────┘└────────┘»
# «    c: 5/════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «                                                                             »
# «q_1 -> 0 ────────────────────────────────────────────────────────────────────»
# «         ┌──────────┐┌──────────┐┌────────┐┌──────────┐ ┌───────┐  ┌────────┐»
# «q_3 -> 1 ┤ Rx(-π/2) ├┤ Rz(-π/2) ├┤0       ├┤ Rz(-π/2) ├─┤ Rx(π) ├──┤0       ├»
# «         └──────────┘└──────────┘│        │└──────────┘ └───────┘  │        │»
# «q_2 -> 2 ────────────────────────┤        ├────────────────────────┤        ├»
# «                                 │  Iswap │                        │  Iswap │»
# «q_4 -> 7 ────────────────────────┤        ├────────────────────────┤        ├»
# «                                 │        │┌──────────┐┌──────────┐│        │»
# «q_0 -> 8 ────────────────────────┤1       ├┤ Rz(-π/2) ├┤ Rx(-π/2) ├┤1       ├»
# «                                 └────────┘└──────────┘└──────────┘└────────┘»
# «    c: 5/════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «                                                                     »
# «q_1 -> 0 ────────────────────────────────────────────────────────────»
# «          ┌────────┐  ┌──────────┐                                   »
# «q_3 -> 1 ─┤ Rz(-π) ├──┤ Rx(-π/2) ├───────────────────────────────────»
# «          └────────┘  └──────────┘                                   »
# «q_2 -> 2 ────────────────────────────────────────────────────────────»
# «                                   ┌────────┐ ┌─────────┐  ┌───────┐ »
# «q_4 -> 7 ──────────────────────────┤0       ├─┤ Rz(π/2) ├──┤ Rx(π) ├─»
# «         ┌─────────┐┌─────────────┐│  Iswap │┌┴─────────┴┐┌┴───────┴┐»
# «q_0 -> 8 ┤ Rx(π/2) ├┤ Rz(-1.7761) ├┤1       ├┤ Rx(-3π/4) ├┤ Rz(π/2) ├»
# «         └─────────┘└─────────────┘└────────┘└───────────┘└─────────┘»
# «    c: 5/════════════════════════════════════════════════════════════»
# «                                                                     »
# «                                                                    »
# «q_1 -> 0 ───────────────────────────────────────────────────────────»
# «                                                          ┌────────┐»
# «q_3 -> 1 ─────────────────────────────────────────────────┤1       ├»
# «                                                          │        │»
# «q_2 -> 2 ─────────────────────────────────────────────────┤        ├»
# «         ┌────────┐ ┌──────────┐ ┌─────────┐┌────────────┐│  Iswap │»
# «q_4 -> 7 ┤0       ├─┤ Rz(-π/2) ├─┤ Rx(π/2) ├┤ Rz(-2.473) ├┤        ├»
# «         │  Iswap │┌┴──────────┴┐├─────────┤└────────────┘│        │»
# «q_0 -> 8 ┤1       ├┤ Rz(2.1467) ├┤ Rx(π/2) ├──────────────┤0       ├»
# «         └────────┘└────────────┘└─────────┘              └────────┘»
# «    c: 5/═══════════════════════════════════════════════════════════»
# «                                                                    »
# «                                                                    »
# «q_1 -> 0 ───────────────────────────────────────────────────────────»
# «         ┌──────────┐┌─────────┐┌────────┐ ┌─────────┐  ┌─────────┐ »
# «q_3 -> 1 ┤ Rx(-π/2) ├┤ Rz(π/2) ├┤1       ├─┤ Rz(π/2) ├──┤ Rx(π/4) ├─»
# «         └──────────┘└─────────┘│        │ └─────────┘  └─────────┘ »
# «q_2 -> 2 ───────────────────────┤        ├──────────────────────────»
# «                                │  Iswap │                          »
# «q_4 -> 7 ───────────────────────┤        ├──────────────────────────»
# «         ┌─────────┐  ┌───────┐ │        │┌────────────┐┌──────────┐»
# «q_0 -> 8 ┤ Rz(π/2) ├──┤ Rx(π) ├─┤0       ├┤ Rx(-1.203) ├┤ Rz(-π/2) ├»
# «         └─────────┘  └───────┘ └────────┘└────────────┘└──────────┘»
# «    c: 5/═══════════════════════════════════════════════════════════»
# «                                                                    »
# «                     ┌────────┐┌─────────┐  ┌───────┐ ┌────────┐┌────────────┐»
# «q_1 -> 0 ────────────┤0       ├┤ Rz(π/2) ├──┤ Rx(π) ├─┤0       ├┤ Rx(1.7955) ├»
# «         ┌──────────┐│  Iswap │├─────────┴┐┌┴───────┴┐│  Iswap │└┬──────────┬┘»
# «q_3 -> 1 ┤ Rz(-π/2) ├┤1       ├┤ Rx(-π/2) ├┤ Rz(π/2) ├┤1       ├─┤ Rz(-π/2) ├─»
# «         └──────────┘└────────┘└──────────┘└─────────┘└────────┘ └──────────┘ »
# «q_2 -> 2 ─────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «q_4 -> 7 ─────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «q_0 -> 8 ─────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «    c: 5/═════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «         ┌─────────┐                                                        »
# «q_1 -> 0 ┤ Rz(π/2) ├────────────────────────────────────────────────────────»
# «         ├─────────┴┐┌──────────┐┌────────┐┌──────────┐┌─────────┐┌────────┐»
# «q_3 -> 1 ┤ Rx(-π/4) ├┤ Rz(-π/2) ├┤1       ├┤ Rx(-π/2) ├┤ Rz(π/2) ├┤1       ├»
# «         └──────────┘└──────────┘│        │└──────────┘└─────────┘│        │»
# «q_2 -> 2 ────────────────────────┤        ├───────────────────────┤        ├»
# «                                 │  Iswap │                       │  Iswap │»
# «q_4 -> 7 ────────────────────────┤        ├───────────────────────┤        ├»
# «                                 │        │┌─────────┐  ┌───────┐ │        │»
# «q_0 -> 8 ────────────────────────┤0       ├┤ Rz(π/2) ├──┤ Rx(π) ├─┤0       ├»
# «                                 └────────┘└─────────┘  └───────┘ └────────┘»
# «    c: 5/═══════════════════════════════════════════════════════════════════»
# «                                                                            »
# «                                                  ┌────────┐┌─────────┐ »
# «q_1 -> 0 ─────────────────────────────────────────┤0       ├┤ Rz(π/2) ├─»
# «           ┌─────────┐   ┌───────────┐┌──────────┐│  Iswap │├─────────┴┐»
# «q_3 -> 1 ──┤ Rz(π/2) ├───┤ Rx(-3π/4) ├┤ Rz(-π/2) ├┤1       ├┤ Rx(-π/2) ├»
# «           └─────────┘   └───────────┘└──────────┘└────────┘└──────────┘»
# «q_2 -> 2 ───────────────────────────────────────────────────────────────»
# «                                                                        »
# «q_4 -> 7 ───────────────────────────────────────────────────────────────»
# «         ┌──────────────┐ ┌─────────┐                                   »
# «q_0 -> 8 ┤ Rx(-0.36353) ├─┤ Rz(π/2) ├───────────────────────────────────»
# «         └──────────────┘ └─────────┘                                   »
# «    c: 5/═══════════════════════════════════════════════════════════════»
# «                                                                        »
# «          ┌───────┐ ┌────────┐┌────────────┐ ┌─────────┐           »
# «q_1 -> 0 ─┤ Rx(π) ├─┤0       ├┤ Rx(1.3773) ├─┤ Rz(π/2) ├───────────»
# «         ┌┴───────┴┐│  Iswap │└┬─────────┬─┘┌┴─────────┴┐┌────────┐»
# «q_3 -> 1 ┤ Rz(π/2) ├┤1       ├─┤ Rz(π/2) ├──┤ Rx(-3π/4) ├┤0       ├»
# «         └─────────┘└────────┘ └─────────┘  └───────────┘│        │»
# «q_2 -> 2 ────────────────────────────────────────────────┤        ├»
# «                                                         │  Iswap │»
# «q_4 -> 7 ────────────────────────────────────────────────┤        ├»
# «                                                         │        │»
# «q_0 -> 8 ────────────────────────────────────────────────┤1       ├»
# «                                                         └────────┘»
# «    c: 5/══════════════════════════════════════════════════════════»
# «                                                                   »
# «                                                                             »
# «q_1 -> 0 ────────────────────────────────────────────────────────────────────»
# «         ┌──────────┐┌──────────┐┌────────┐┌──────────┐ ┌───────┐  ┌────────┐»
# «q_3 -> 1 ┤ Rx(-π/2) ├┤ Rz(-π/2) ├┤0       ├┤ Rz(-π/2) ├─┤ Rx(π) ├──┤0       ├»
# «         └──────────┘└──────────┘│        │└──────────┘ └───────┘  │        │»
# «q_2 -> 2 ────────────────────────┤        ├────────────────────────┤        ├»
# «                                 │  Iswap │                        │  Iswap │»
# «q_4 -> 7 ────────────────────────┤        ├────────────────────────┤        ├»
# «                                 │        │┌──────────┐┌──────────┐│        │»
# «q_0 -> 8 ────────────────────────┤1       ├┤ Rz(-π/2) ├┤ Rx(-π/2) ├┤1       ├»
# «                                 └────────┘└──────────┘└──────────┘└────────┘»
# «    c: 5/════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «                                   ┌────────┐ ┌─────────┐  ┌───────┐ »
# «q_1 -> 0 ──────────────────────────┤0       ├─┤ Rz(π/2) ├──┤ Rx(π) ├─»
# «         ┌────────────┐ ┌───────┐  │  Iswap │┌┴─────────┴┐┌┴───────┴┐»
# «q_3 -> 1 ┤ Rz(2.6788) ├─┤ Rx(π) ├──┤1       ├┤ Rx(-3π/4) ├┤ Rz(π/2) ├»
# «         └────────────┘ └───────┘  └────────┘└───────────┘└─────────┘»
# «q_2 -> 2 ────────────────────────────────────────────────────────────»
# «                                                                     »
# «q_4 -> 7 ────────────────────────────────────────────────────────────»
# «          ┌─────────┐  ┌──────────┐                                  »
# «q_0 -> 8 ─┤ Rz(π/2) ├──┤ Rx(-π/2) ├──────────────────────────────────»
# «          └─────────┘  └──────────┘                                  »
# «    c: 5/════════════════════════════════════════════════════════════»
# «                                                                     »
# «         ┌────────┐  ┌─────────┐  ┌─────────┐┌────────────┐ ░          ┌─┐
# «q_1 -> 0 ┤0       ├──┤ Rz(π/2) ├──┤ Rx(π/2) ├┤ Rz(2.1231) ├─░──────────┤M├───
# «         │  Iswap │┌─┴─────────┴─┐└─────────┘└────────────┘ ░       ┌─┐└╥┘
# «q_3 -> 1 ┤1       ├┤ Rz(-2.6788) ├──────────────────────────░───────┤M├─╫────
# «         └────────┘└─────────────┘                          ░    ┌─┐└╥┘ ║
# «q_2 -> 2 ───────────────────────────────────────────────────░────┤M├─╫──╫────
# «                                                            ░    └╥┘ ║  ║ ┌─┐
# «q_4 -> 7 ───────────────────────────────────────────────────░─────╫──╫──╫─┤M├
# «                                                            ░ ┌─┐ ║  ║  ║ └╥┘
# «q_0 -> 8 ───────────────────────────────────────────────────░─┤M├─╫──╫──╫──╫─
# «                                                            ░ └╥┘ ║  ║  ║  ║
# «    c: 5/══════════════════════════════════════════════════════╩══╩══╩══╩══╩═
# «                                                               0  1  2  3  4

# %%
from qiskit.providers.jobstatus import JobStatus
import time

job = backend.run(trans_qc, shots=1024)

print("Job ID is", job.job_id(),"\n")

# 제출된 잡에 대한 지속적인 실행 상태 확인
#while job.status() is not JobStatus.DONE:
#	print("Job status is", job.status() )
#	time.sleep(2)
###while
# Out:
# Job ID is arn:aws:braket:us-west-1:590183937332:quantum-task/671f7444-d90e-4d12-b12a-8287cd47d114

# %%
print("Job status is", job.status() )
# Out:
# Job status is JobStatus.DONE

# %%
# 중간에 세션이 종료된 경우 기존에 실행이 완료된 Job을 복구하는 방법
#job = backend.retrieve_job("arn:aws:braket:us-east-1:746669231099:quantum-task/f6fab6be-1590-4da0-914a-fade74efc485")

# %%
result = job.result()
result
# Out:
# Result(backend_name='Ankaa-3', backend_version='2', job_id='arn:aws:braket:us-west-1:590183937332:quantum-task/671f7444-d90e-4d12-b12a-8287cd47d114', success=True, results=[ExperimentResult(shots=1024, success=True, meas_level=2, data=ExperimentResultData(counts={'11010': 31, '01000': 74, '10010': 38, '01010': 77, '00111': 14, '01110': 14, '01100': 22, '00100': 16, '00001': 72, '01001': 61, '10101': 13, '00101': 17, '00000': 89, '11011': 31, '10000': 22, '10110': 13, '00011': 50, '00010': 61, '10001': 37, '10011': 45, '11001': 36, '10111': 13, '01011': 51, '11110': 8, '11000': 33, '11111': 18, '00110': 14, '01111': 20, '11100': 7, '01101': 10, '11101': 10, '10100': 7}, memory=['11010', '01000', '10010', '01010', '00111', '11010', '01110', '01100', '10010', '01010', '00100', '00001', '11010', '00111', '01001', '10101', '00101', '01010', '00000', '11011', '00000', '00101', '00000', '10000', '10010', '00001', '10000', '00101', '10110', '00011', '10000', '00010', '00000', '10001', '01010', '01000', '00000', '00000', '01000', '00011', '01000', '10011', '11001', '10010', '00010', '10111', '10001', '00001', '01011', '00100', '00010', '00101', '01000', '10010', '11110', '01100', '01110', '11110', '00010', '01000', '10011', '00010', '00000', '11000', '00000', '10000', '10000', '11111', '10011', '10000', '01000', '00000', '00111', '00111', '10000', '01000', '00001', '01000', '00010', '01001', '00000', '00001', '10001', '10101', '00110', '11001', '11011', '01010', '00001', '00001', '10001', '01000', '11010', '00000', '01010', '11010', '00001', '01010', '01011', '11011', '00110', '10001', '01000', '00001', '01111', '00000', '00010', '10011', '01000', '01011', '00011', '00010', '00001', '01100', '11111', '11011', '11001', '10101', '01000', '01011', '11000', '10111', '00011', '00011', '11000', '11100', '01000', '00010', '10001', '00000', '00001', '00111', '00000', '00001', '01001', '01000', '00000', '00011', '11011', '11001', '10011', '11010', '00010', '01111', '01001', '01011', '01000', '11111', '11010', '10011', '00011', '00000', '00011', '00010', '00000', '01100', '01010', '11000', '00010', '00001', '01001', '10110', '00001', '11111', '01110', '00111', '11001', '11011', '00001', '01011', '10011', '11000', '00000', '00010', '01000', '11000', '01000', '10101', '11010', '01000', '01010', '10011', '01110', '11011', '10011', '11011', '00011', '11001', '11000', '10001', '01000', '01010', '10011', '00001', '01010', '10011', '00010', '10110', '11001', '10010', '00011', '00010', '00011', '10010', '11001', '00010', '11010', '01001', '00010', '10110', '10010', '01110', '00101', '00011', '01010', '01111', '11011', '00000', '01001', '10001', '11001', '00010', '11000', '11110', '11001', '00011', '10001', '01000', '00000', '00111', '01101', '00001', '11101', '00111', '10111', '01011', '11001', '11010', '00100', '11000', '00001', '00011', '00000', '00010', '00011', '01101', '01100', '00100', '01111', '01001', '00011', '01111', '11010', '00010', '10010', '11111', '00100', '00011', '01000', '00100', '00010', '00000', '01010', '11000', '10001', '01000', '01011', '00010', '11011', '01101', '11000', '00011', '01010', '00011', '01001', '00101', '10110', '00010', '10011', '10100', '10001', '00100', '11001', '00011', '01010', '00010', '00011', '01000', '00000', '00001', '00001', '10001', '10010', '10001', '01001', '00010', '10011', '11000', '10011', '01001', '11101', '10000', '10010', '10011', '10011', '00000', '00010', '01000', '10011', '01001', '00011', '01010', '01001', '01001', '01010', '10011', '10001', '00100', '10011', '01000', '11111', '00111', '01000', '10111', '11011', '10000', '00000', '01010', '01010', '00100', '11000', '11000', '00001', '00110', '10011', '00000', '11101', '11010', '00010', '01110', '00001', '10010', '10101', '00000', '11001', '01110', '00011', '11000', '10110', '10010', '10001', '11010', '11111', '11000', '01000', '00001', '11011', '01101', '10100', '00111', '11010', '01101', '00100', '01111', '10001', '01000', '01001', '01011', '0 ...

# %%
# 결과 출력
counts = result.get_counts()
print(counts)
# Out:
# {'11010': 31, '01000': 74, '10010': 38, '01010': 77, '00111': 14, '01110': 14, '01100': 22, '00100': 16, '00001': 72, '01001': 61, '10101': 13, '00101': 17, '00000': 89, '11011': 31, '10000': 22, '10110': 13, '00011': 50, '00010': 61, '10001': 37, '10011': 45, '11001': 36, '10111': 13, '01011': 51, '11110': 8, '11000': 33, '11111': 18, '00110': 14, '01111': 20, '11100': 7, '01101': 10, '11101': 10, '10100': 7}

# %%
from qiskit.visualization import plot_histogram
plot_histogram(data=counts)

# %%
print("Quantum Task Summary\n")
print(t.quantum_tasks_statistics())
print('\nNote: Charges shown are estimates based on your Amazon Braket simulator and quantum processing unit (QPU) task usage. \nEstimated charges shown may differ from your actual charges. \nEstimated charges do not factor in any discounts or credits, \nand you may experience additional charges based on your use of other services such as Amazon Elastic Compute Cloud (Amazon EC2).')
print(f"\nEstimated cost to run this example: {t.qpu_tasks_cost() + t.simulator_tasks_cost():.2f} USD")
# Out:
# Quantum Task Summary
#
# {'arn:aws:braket:::device/quantum-simulator/amazon/sv1': {'shots': 1024, 'tasks': {'COMPLETED': 1}, 'execution_duration': datetime.timedelta(microseconds=4000), 'billed_execution_duration': datetime.timedelta(seconds=3)}, 'arn:aws:braket:us-west-1::device/qpu/rigetti/Ankaa-3': {'shots': 1024, 'tasks': {'COMPLETED': 1}}}
#
# Note: Charges shown are estimates based on your Amazon Braket simulator and quantum processing unit (QPU) task usage.
# Estimated charges shown may differ from your actual charges.
# Estimated charges do not factor in any discounts or credits,
# and you may experience additional charges based on your use of other services such as Amazon Elastic Compute Cloud (Amazon EC2).
#
# Estimated cost to run this example: 1.23 USD
