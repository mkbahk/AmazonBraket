# %% [markdown]
# <a href="https://colab.research.google.com/github/mkbahk/AmazonBraket/blob/main/QiskitAer_RunningwithThreadpool_mkbahk_20251222.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip uninstall qiskit qiskit-aer qiskit-aer-gpu qiskit-ibm-runtime -y
# Out:
# WARNING: Skipping qiskit as it is not installed.
# WARNING: Skipping qiskit-aer as it is not installed.
# WARNING: Skipping qiskit-aer-gpu as it is not installed.
# WARNING: Skipping qiskit-ibm-runtime as it is not installed.

# %%
# !pip install qiskit[visualization]
# !pip install qiskit-aer
#!pip install qiskit-aer-gpu==0.15.1
# !pip install qiskit-ibm-runtime
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 21.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 86.2 MB/s eta 0:00:00
# ...
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136817 sha256=102c0a6ba9c0232c78fe0c83b4c8021b1aeacdd7ca7f49e5739bbeca8d82f1b6
#   Stored in directory: /root/.cache/pip/wheels/06/3e/78/fa1588c1ae991bbfd814af2bcac6cef7a178beee1939180d46
# Successfully built pylatexenc
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 42.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 378.5/378.5 kB 24.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.8/75.8 kB 3.7 MB/s eta 0:00:00
# ...

# %%
# %pip show qiskit
# %pip show qiskit-aer
#%pip show qiskit-aer-gpu
# %pip show qiskit-ibm-runtime
# Out:
# Name: qiskit
# Version: 2.2.3
# Summary: An open-source SDK for working with quantum computers at the level of extended quantum circuits, operators, and primitives.
# Home-page: https://www.ibm.com/quantum/qiskit
# Author:
# Author-email: Qiskit Development Team <qiskit@us.ibm.com>
# License: Apache 2.0
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: dill, numpy, rustworkx, scipy, stevedore, typing-extensions
# Required-by: qiskit-aer, qiskit-ibm-runtime
# Name: qiskit-aer
# Version: 0.17.2
# Summary: Aer - High performance simulators for Qiskit
# Home-page: https://github.com/Qiskit/qiskit-aer
# Author: AER Development Team
# Author-email: qiskit@us.ibm.com
# License: Apache 2.0
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: numpy, psutil, python-dateutil, qiskit, scipy
# Required-by:
# Name: qiskit-ibm-runtime
# Version: 0.44.0
# Summary: IBM Quantum client for Qiskit Runtime.
# Home-page:
# Author:
# ...

# %%
import qiskit
from concurrent.futures import ThreadPoolExecutor
from qiskit_aer import AerSimulator
from math import pi

# Generate circuit
circ = qiskit.QuantumCircuit(15, 15)
circ.h(0)
circ.cx(0, 1)
circ.cx(1, 2)
circ.p(pi/2, 2)
circ.measure([0, 1, 2], [0, 1 ,2])

circ2 = qiskit.QuantumCircuit(15, 15)
circ2.h(0)
circ2.cx(0, 1)
circ2.cx(1, 2)
circ2.p(pi/2, 2)
circ2.measure([0, 1, 2], [0, 1 ,2])
circ_list = [circ, circ2]

qbackend = AerSimulator()
# Set executor and max_job_size
exc = ThreadPoolExecutor(max_workers=2)
qbackend.set_options(executor=exc)
qbackend.set_options(max_job_size=1)
result = qbackend.run(circ_list).result()

# %%
result
# Out:
# Result(backend_name='aer_simulator', backend_version='0.17.2', job_id='e226aa30-b3c2-459e-9923-2fb431d2aff1', success=True, results=[ExperimentResult(shots=1024, success=True, meas_level=2, data=ExperimentResultData(counts={'0x7': 511, '0x0': 513}), header={'creg_sizes': [['c', 15]], 'global_phase': 0.0, 'memory_slots': 15, 'n_qubits': 15, 'name': 'circuit-46', 'qreg_sizes': [['q', 15]], 'metadata': {}}, status=DONE, seed_simulator=2727314251, metadata={'time_taken': 0.005735726, 'num_bind_params': 1, 'parallel_state_update': 2, 'parallel_shots': 1, 'required_memory_mb': 1, 'input_qubit_map': [[2, 2], [1, 1], [0, 0]], 'method': 'statevector', 'device': 'CPU', 'num_qubits': 3, 'sample_measure_time': 0.004152673, 'active_input_qubits': [0, 1, 2], 'num_clbits': 15, 'remapped_qubits': False, 'runtime_parameter_bind': False, 'max_memory_mb': 12975, 'noise': 'ideal', 'measure_sampling': True, 'batched_shots_optimization': False, 'fusion': {'applied': False, 'max_fused_qubits': 5, 'threshol
# ...
