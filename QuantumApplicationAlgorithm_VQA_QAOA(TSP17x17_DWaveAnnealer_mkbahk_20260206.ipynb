# %% [markdown]
# <a href="https://colab.research.google.com/github/mkbahk/AmazonBraket/blob/main/QuantumApplicationAlgorithm_VQA_QAOA(TSP17x17_DWaveAnnealer_mkbahk_20260206.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install dwave-ocean-sdk==9.3.0
#%pip install dwave-networkx
# Out:
# Collecting dwave-ocean-sdk==9.3.0
#   Downloading dwave_ocean_sdk-9.3.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting dimod==0.12.21 (from dwave-ocean-sdk==9.3.0)
#   Downloading dimod-0.12.21-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.0 kB)
# Collecting dwave-cloud-client==0.14.4 (from dwave-ocean-sdk==9.3.0)
#   Downloading dwave_cloud_client-0.14.4-py3-none-any.whl.metadata (5.4 kB)
# Collecting dwave-gate==0.3.5 (from dwave-ocean-sdk==9.3.0)
#   Downloading dwave_gate-0.3.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (18 kB)
# Collecting dwave-hybrid==0.6.15 (from dwave-ocean-sdk==9.3.0)
#   Downloading dwave_hybrid-0.6.15-py3-none-any.whl.metadata (4.5 kB)
# Collecting dwave-inspector==0.5.5 (from dwave-ocean-sdk==9.3.0)
#   Downloading dwave_inspector-0.5.5-py3-none-any.whl.metadata (4.4 kB)
# Collecting dwave-networkx==0.8.18 (from dwave-ocean-sdk==9.3.0)
#   Downloading dwave_networkx-0.8.18-py3-none-any.whl.metadata (2.7 kB)
# Collecting dwave-optimization==0.6.11 (from dwave-ocean-sdk==9.3.0)
#   Downloading dwave_optimization-0.6.11-cp312-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (19 kB)
# Collecting dwave-preprocessing==0.6.11 (from dwave-ocean-sdk==9.3.0)
#   Downloading dwave_preprocessing-0.6.11-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.5 kB)
# Collecting dwave-samplers==1.7.0 (from dwave-ocean-sdk==9.3.0)
#   Downloading dwave_samplers-1.7.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting dwave-system==1.34.0 (from dwave-ocean-sdk==9.3.0)
#   Downloading dwave_system-1.34.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting minorminer==0.2.21 (from dwave-ocean-sdk==9.3.0)
#   Downloading minorminer-0.2.21-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (7.9 kB)
# Collecting penaltymodel==1.3.0 (from dwave-ocean-sdk==9.3.0)
#   Downloading penaltymodel-1.3.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.12/dist-packages (from dimod==0.12.21->dwave-ocean-sdk==9.3.0) (2.0.2)
# Requirement already satisfied: requests<3,>=2.25 in /usr/local/lib/python3.12/dist-packages (from requests[socks]<3,>=2.25->dwave-cloud-client==0.14.4->dwave-ocean-sdk==9.3.0) (2.32.4)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from dwave-cloud-client==0.14.4->dwave-ocean-sdk==9.3.0) (2.5.0)
# Requirement already satisfied: pydantic<3,>=2 in /usr/local/lib/python3.12/dist-packages (from dwave-cloud-client==0.14.4->dwave-ocean-sdk==9.3.0) (2.12.3)
# Collecting homebase<2,>=1.0 (from dwave-cloud-client==0.14.4->dwave-ocean-sdk==9.3.0)
#   Downloading homebase-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: click<9,>=8.2 in /usr/local/lib/python3.12/dist-packages (from dwave-cloud-client==0.14.4->dwave-ocean-sdk==9.3.0) (8.3.1)
# Requirement already satisfied: python-dateutil<3,>=2.7 in /usr/local/lib/python3.12/dist-packages (from dwave-cloud-client==0.14.4->dwave-ocean-sdk==9.3.0) (2.9.0.post0)
# Collecting plucky<0.5,>=0.4.3 (from dwave-cloud-client==0.14.4->dwave-ocean-sdk==9.3.0)
#   Downloading plucky-0.4.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting diskcache<6,>=5.2.1 (from dwave-cloud-client==0.14.4->dwave-ocean-sdk==9.3.0)
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: packaging>=19 in /usr/local/lib/python3.12/dist-packages (from dwave-cloud-client==0.14.4->dwave-ocean-sdk==9.3.0) (26.0)
# Requirement already satisfied: werkzeug<4,>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from dwave-cloud-client==0.14.4->dwave-ocean-sdk==9.3.0) (3.1.5)
# Requirement already satisfied: typing-extensions<5,>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from dwave-cloud-client==0.14.4->dwave-ocean-sdk==9.3.0) (4.15.0)
# Requirement already satisfied: authlib<2,>=1.2 in /usr/local/lib/python3.12/dist-packages (from dwave-cloud-client==0.14.4->dwave-ocean-sdk==9.3.0) (1.6.6)
# Requirement already satisfied: importlib_metadata>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from dwave-cloud-client==0.14.4->dwave-ocean-sdk==9.3.0) (8.7.1)
# Requirement already satisfied: orjson>=3.11 in /usr/local/lib/python3.12/dist-packages (from dwave-cloud-client==0.14.4->dwave-ocean-sdk==9.3.0) (3.11.7)
# Collecting http-sf>=1.0.4 (from dwave-cloud-client==0.14.4->dwave-ocean-sdk==9.3.0)
#   Downloading http_sf-1.1.1-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from dwave-hybrid==0.6.15->dwave-ocean-sdk==9.3.0) (3.6.1)
# Requirement already satisfied: Flask<4,>=2.2 in /usr/local/lib/python3.12/dist-packages (from dwave-inspector==0.5.5->dwave-ocean-sdk==9.3.0) (3.1.2)
# Requirement already satisfied: scipy>=1.7.3 in /usr/local/lib/python3.12/dist-packages (from dwave-system==1.34.0->dwave-ocean-sdk==9.3.0) (1.16.3)
# Collecting fasteners>=0.15 (from minorminer==0.2.21->dwave-ocean-sdk==9.3.0)
#   Downloading fasteners-0.20-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.12/dist-packages (from authlib<2,>=1.2->dwave-cloud-client==0.14.4->dwave-ocean-sdk==9.3.0) (43.0.3)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from Flask<4,>=2.2->dwave-inspector==0.5.5->dwave-ocean-sdk==9.3.0) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from Flask<4,>=2.2->dwave-inspector==0.5.5->dwave-ocean-sdk==9.3.0) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from Flask<4,>=2.2->dwave-inspector==0.5.5->dwave-ocean-sdk==9.3.0) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from Flask<4,>=2.2->dwave-inspector==0.5.5->dwave-ocean-sdk==9.3.0) (3.0.3)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata>=5.0.0->dwave-cloud-client==0.14.4->dwave-ocean-sdk==9.3.0) (3.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2->dwave-cloud-client==0.14.4->dwave-ocean-sdk==9.3.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2->dwave-cloud-client==0.14.4->dwave-ocean-sdk==9.3.0) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2->dwave-cloud-client==0.14.4->dwave-ocean-sdk==9.3.0) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3,>=2.7->dwave-cloud-client==0.14.4->dwave-ocean-sdk==9.3.0) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.25->requests[socks]<3,>=2.25->dwave-cloud-client==0.14.4->dwave-ocean-sdk==9.3.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.25->requests[socks]<3,>=2.25->dwave-cloud-client==0.14.4->dwave-ocean-sdk==9.3.0) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.25->requests[socks]<3,>=2.25->dwave-cloud-client==0.14.4->dwave-ocean-sdk==9.3.0) (2026.1.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]<3,>=2.25->dwave-cloud-client==0.14.4->dwave-ocean-sdk==9.3.0) (1.7.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography->authlib<2,>=1.2->dwave-cloud-client==0.14.4->dwave-ocean-sdk==9.3.0) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography->authlib<2,>=1.2->dwave-cloud-client==0.14.4->dwave-ocean-sdk==9.3.0) (3.0)
# Downloading dwave_ocean_sdk-9.3.0-py3-none-any.whl (8.4 kB)
# Downloading dimod-0.12.21-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 53.5 MB/s eta 0:00:00
# Downloading dwave_cloud_client-0.14.4-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.5/167.5 kB 13.8 MB/s eta 0:00:00
# Downloading dwave_gate-0.3.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 71.5 MB/s eta 0:00:00
# Downloading dwave_hybrid-0.6.15-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 4.9 MB/s eta 0:00:00
# Downloading dwave_inspector-0.5.5-py3-none-any.whl (30 kB)
# Downloading dwave_networkx-0.8.18-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.5/106.5 kB 6.0 MB/s eta 0:00:00
# Downloading dwave_optimization-0.6.11-cp312-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (14.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 64.7 MB/s eta 0:00:00
# Downloading dwave_preprocessing-0.6.11-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 62.1 MB/s eta 0:00:00
# Downloading dwave_samplers-1.7.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 72.9 MB/s eta 0:00:00
# Downloading dwave_system-1.34.0-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.1/119.1 kB 9.0 MB/s eta 0:00:00
# Downloading minorminer-0.2.21-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 103.2 MB/s eta 0:00:00
# Downloading penaltymodel-1.3.0-py3-none-any.whl (36 kB)
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 3.5 MB/s eta 0:00:00
# Downloading fasteners-0.20-py3-none-any.whl (18 kB)
# Downloading homebase-1.0.1-py2.py3-none-any.whl (11 kB)
# Downloading http_sf-1.1.1-py3-none-any.whl (26 kB)
# Downloading plucky-0.4.3-py2.py3-none-any.whl (10 kB)
# Installing collected packages: plucky, homebase, http-sf, fasteners, dwave-optimization, dwave-gate, diskcache, dimod, penaltymodel, dwave-samplers, dwave-preprocessing, dwave-networkx, minorminer, dwave-cloud-client, dwave-system, dwave-inspector, dwave-hybrid, dwave-ocean-sdk
# Successfully installed dimod-0.12.21 diskcache-5.6.3 dwave-cloud-client-0.14.4 dwave-gate-0.3.5 dwave-hybrid-0.6.15 dwave-inspector-0.5.5 dwave-networkx-0.8.18 dwave-ocean-sdk-9.3.0 dwave-optimization-0.6.11 dwave-preprocessing-0.6.11 dwave-samplers-1.7.0 dwave-system-1.34.0 fasteners-0.20 homebase-1.0.1 http-sf-1.1.1 minorminer-0.2.21 penaltymodel-1.3.0 plucky-0.4.3

# %%
import networkx as nx
import dwave_networkx as dnx

#from neal import SimulatedAnnealingSampler
from dimod import SimulatedAnnealingSampler # Changed import from neal to dimod
import numpy as np

# %%
#
#대한민국의 모든 시도청을 가장 짦은 경로로 여행하고 싶다.
#
# 17개 도시 목록 (인덱스 순서), 거리단위는 Km
# 0:서울, 1:인천, 2:경기(수원), 3:강원(춘천), 4:충북(청주), 5:충남(홍성), 6:세종, 7:대전,
# 8:전북(전주), 9:전남(무안), 10:경북(안동), 11:경남(창원), 12:제주, 13:부산, 14:울산, 15:대구, 16:광주

distance_matrix = np.array([
    [  0,  32,  35, 105, 135, 130, 132, 160, 210, 340, 235, 350, 450, 390, 375, 285, 290],   # 0: 서울
    [ 32,   0,  42, 135, 145, 105, 140, 165, 205, 330, 255, 355, 445, 400, 385, 300, 285],   # 1: 인천
    [ 35,  42,   0, 120, 105,  95, 105, 130, 175, 305, 215, 320, 415, 365, 350, 265, 260],    # 2: 경기
    [105, 135, 120,   0, 170, 225, 195, 215, 305, 430, 230, 390, 540, 415, 370, 290, 385],  # 3: 강원
    [135, 145, 105, 170,   0,  90,  35,  45, 110, 245, 130, 240, 360, 285, 270, 180, 195],    # 4: 충북
    [130, 105,  95, 225,  90,   0,  75,  90, 105, 230, 225, 285, 345, 335, 330, 245, 185],     # 5: 충남
    [132, 140, 105, 195,  35,  75,   0,  25,  95, 230, 155, 245, 345, 290, 280, 190, 180],     # 6: 세종
    [160, 165, 130, 215,  45,  90,  25,   0,  85, 215, 150, 230, 330, 265, 255, 165, 165],     # 7: 대전
    [210, 205, 175, 305, 110, 105,  95,  85,   0, 135, 215, 205, 255, 260, 265, 195,  90],    # 8: 전북
    [340, 330, 305, 430, 245, 230, 230, 215, 135,   0, 345, 260, 180, 305, 330, 290,  65],   # 9: 전남
    [235, 255, 215, 230, 130, 225, 155, 150, 215, 345,   0, 185, 435, 165, 145, 105, 280],  # 10: 경북
    [350, 355, 320, 390, 240, 285, 245, 230, 205, 260, 185,   0, 280,  45,  70, 100, 210],    # 11: 경남
    [450, 445, 415, 540, 360, 345, 345, 330, 255, 180, 435, 280,   0, 310, 340, 380, 240],  # 12: 제주
    [390, 400, 365, 415, 285, 335, 290, 265, 260, 305, 165,  45, 310,   0,  55, 115, 255],    # 13: 부산
    [375, 385, 350, 370, 270, 330, 280, 255, 265, 330, 145,  70, 340,  55,   0,  95, 280],     # 14: 울산
    [285, 300, 265, 290, 180, 245, 190, 165, 195, 290, 105, 100, 380, 115,  95,   0, 205],   # 15: 대구
    [290, 285, 260, 385, 195, 185, 180, 165,  90,  65, 280, 210, 240, 255, 280, 205,   0]     # 16: 광주
])

print(f"Matrix Shape: {distance_matrix.shape}")
# Out:
# Matrix Shape: (17, 17)

# %%
# 2. NetworkX 그래프 객체 생성
G = nx.Graph()
num_cities = len(distance_matrix)

for i in range(num_cities):
    for j in range(i + 1, num_cities):
        # 도시 i와 j 사이에 거리를 가중치(weight)로 추가
        G.add_edge(i, j, weight=distance_matrix[i][j])
    ###for
###for

# %%
# 3. 샘플러(Sampler) 설정
# D-Wave QPU 실제 장비 대신 로컬 시뮬레이터(SimulatedAnnealingSampler)를 사용합니다.
sampler = SimulatedAnnealingSampler()

# %%
# 4. TSP 문제 해결 (dwave-networkx 활용)
# 이 함수는 내부적으로 TSP를 QUBO(Quadratic Unconstrained Binary Optimization) 형태로 변환하여 샘플링합니다.
best_path = dnx.traveling_salesperson(G, sampler, weight='weight')

# %%
# `dnx.traveling_salesperson` 함수는 내부적으로 TSP 문제를 BQM(Binary Quadratic Model)로 변환하여 샘플러에 전달합니다.
# `dimod.SimulatedAnnealingSampler`는 각 샘플링 단계에서 콜백을 제공하지 않으며, 최종적인 SampleSet을 반환합니다.
# 따라서 `dnx.traveling_salesperson` 함수는 계산 과정의 히스토리를 직접 볼 수 있는 콜백 함수를 제공하지 않습니다.

# %%
# 5. 결과 출력
print("--- TSP 최적 경로 계산 결과 ---")
if best_path:
    print(f"최적 경로: {best_path}")

    # 총 이동 거리 계산
    total_distance = 0
    for k in range(len(best_path) - 1):
        total_distance += distance_matrix[best_path[k]][best_path[k+1]]
    ###for
    # 마지막 도시에서 시작 도시로 돌아오는 거리 추가
    total_distance += distance_matrix[best_path[-1]][best_path[0]]

    print(f"총 이동 거리: {total_distance}")
else:
    print("경로를 찾지 못했습니다.")
###if
# Out:
# --- TSP 최적 경로 계산 결과 ---
# 최적 경로: [13, 10, 14, 5, 1, 0, 11, 15, 2, 7, 16, 6, 9, 3, 12, 8, 4]
# 총 이동 거리: 3817

# %%
import matplotlib.pyplot as plt

# %%
# 7. 시각화 (도시가 많으므로 경로 위주로 시각화)
plt.figure(figsize=(12, 8))
pos = nx.spring_layout(G, seed=42)

# 노드 그리기
nx.draw_networkx_nodes(G, pos, node_size=500, node_color='skyblue')
nx.draw_networkx_labels(G, pos, font_size=10, font_weight='bold')

# 최적 경로 강조
if best_path:
    path_edges = [(best_path[i], best_path[(i+1)%len(best_path)]) for i in range(len(best_path))]
    nx.draw_networkx_edges(G, pos, edgelist=path_edges, edge_color='red', width=2)
###if

plt.title(f"D-Wave Simulated Annealing: {17}x{17} TSP\nTotal Distance: {total_distance}")
plt.axis('off')
plt.show()

# %% [markdown]
# DWave 양자컴퓨터에서 TSP풀때 최대능력치: https://grok.com/share/bGVnYWN5LWNvcHk_3ac5507f-09dc-4bf5-893a-c3d917c91906

# %% [markdown]
# ![스크린샷 2026-02-06 오후 2.18.18.png](data:image/png;base64,...)
