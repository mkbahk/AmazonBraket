# %% [markdown]
# <a href="https://colab.research.google.com/github/mkbahk/AmazonBraket/blob/main/QCTL_FireOpal_Access_to_IonQ_with_NoErrorSupression_mkbahk_20250410.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 작업순서
# 1. Amazon Braket 환경 설정(확인만)
# 2. S3 환경설정(확인만)
# 3. (중요) IAM을 이용한 Access Key 설정 및 권한 부여
# 4. 원격 작업
# 5. 각종 로그 보기
# 6. 작업 환경 정리

# %% [markdown]
# ![스크린샷 2025-01-06 오전 7.51.00.png](data:image/png;base64,...)

# %%
# !python3 -m pip install qiskit[visualization]==1.2.4
# !python3 -m pip install qiskit-braket-provider==0.4.5
# !python3 -m pip install amazon-braket-sdk==1.88.3
#!python3 -m pip install boto3
#!python3 -m pip install botocore
# Out:
# Collecting qiskit==1.2.4 (from qiskit[visualization]==1.2.4)
#   Downloading qiskit-1.2.4-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting rustworkx>=0.15.0 (from qiskit==1.2.4->qiskit[visualization]==1.2.4)
#   Using cached rustworkx-0.16.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: numpy<3,>=1.17 in /usr/local/lib/python3.11/dist-packages (from qiskit==1.2.4->qiskit[visualization]==1.2.4) (2.0.2)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.11/dist-packages (from qiskit==1.2.4->qiskit[visualization]==1.2.4) (1.14.1)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.11/dist-packages (from qiskit==1.2.4->qiskit[visualization]==1.2.4) (1.13.1)
# Collecting dill>=0.3 (from qiskit==1.2.4->qiskit[visualization]==1.2.4)
#   Using cached dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from qiskit==1.2.4->qiskit[visualization]==1.2.4) (2.8.2)
# Collecting stevedore>=3.0.0 (from qiskit==1.2.4->qiskit[visualization]==1.2.4)
#   Using cached stevedore-5.4.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from qiskit==1.2.4->qiskit[visualization]==1.2.4) (4.13.1)
# Collecting symengine<0.14,>=0.11 (from qiskit==1.2.4->qiskit[visualization]==1.2.4)
#   Downloading symengine-0.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.11/dist-packages (from qiskit[visualization]==1.2.4) (3.10.0)
# Requirement already satisfied: pydot in /usr/local/lib/python3.11/dist-packages (from qiskit[visualization]==1.2.4) (3.0.4)
# Requirement already satisfied: Pillow>=4.2.1 in /usr/local/lib/python3.11/dist-packages (from qiskit[visualization]==1.2.4) (11.1.0)
# Collecting pylatexenc>=1.4 (from qiskit[visualization]==1.2.4)
#   Using cached pylatexenc-2.10-py3-none-any.whl
# Requirement already satisfied: seaborn>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from qiskit[visualization]==1.2.4) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->qiskit[visualization]==1.2.4) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->qiskit[visualization]==1.2.4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->qiskit[visualization]==1.2.4) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->qiskit[visualization]==1.2.4) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->qiskit[visualization]==1.2.4) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->qiskit[visualization]==1.2.4) (3.2.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.0->qiskit==1.2.4->qiskit[visualization]==1.2.4) (1.17.0)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.11/dist-packages (from seaborn>=0.9.0->qiskit[visualization]==1.2.4) (2.2.2)
# Collecting pbr>=2.0.0 (from stevedore>=3.0.0->qiskit==1.2.4->qiskit[visualization]==1.2.4)
#   Using cached pbr-6.1.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy>=1.3->qiskit==1.2.4->qiskit[visualization]==1.2.4) (1.3.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn>=0.9.0->qiskit[visualization]==1.2.4) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn>=0.9.0->qiskit[visualization]==1.2.4) (2025.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from pbr>=2.0.0->stevedore>=3.0.0->qiskit==1.2.4->qiskit[visualization]==1.2.4) (75.2.0)
# Downloading qiskit-1.2.4-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 41.6 MB/s eta 0:00:00
# Using cached dill-0.3.9-py3-none-any.whl (119 kB)
# Using cached rustworkx-0.16.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
# Using cached stevedore-5.4.1-py3-none-any.whl (49 kB)
# Downloading symengine-0.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 MB 18.6 MB/s eta 0:00:00
# Using cached pbr-6.1.1-py2.py3-none-any.whl (108 kB)
# Installing collected packages: pylatexenc, symengine, rustworkx, pbr, dill, stevedore, qiskit
# Successfully installed dill-0.3.9 pbr-6.1.1 pylatexenc-2.10 qiskit-1.2.4 rustworkx-0.16.0 stevedore-5.4.1 symengine-0.13.0
# Collecting qiskit-braket-provider
#   Using cached qiskit_braket_provider-0.4.5-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: certifi>=2021.5.30 in /usr/local/lib/python3.11/dist-packages (from qiskit-braket-provider) (2025.1.31)
# Requirement already satisfied: qiskit<2.0,>=0.34.2 in /usr/local/lib/python3.11/dist-packages (from qiskit-braket-provider) (1.2.4)
# Collecting qiskit-ionq>=0.5.2 (from qiskit-braket-provider)
#   Using cached qiskit_ionq-0.5.13-py3-none-any.whl.metadata (8.1 kB)
# Collecting amazon-braket-sdk>=1.76.0 (from qiskit-braket-provider)
#   Using cached amazon_braket_sdk-1.91.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: setuptools>=40.1.0 in /usr/local/lib/python3.11/dist-packages (from qiskit-braket-provider) (75.2.0)
# Requirement already satisfied: numpy>=1.3 in /usr/local/lib/python3.11/dist-packages (from qiskit-braket-provider) (2.0.2)
# Collecting amazon-braket-schemas>=1.23.0 (from amazon-braket-sdk>=1.76.0->qiskit-braket-provider)
#   Using cached amazon_braket_schemas-1.23.3-py3-none-any.whl.metadata (6.1 kB)
# Collecting amazon-braket-default-simulator>=1.26.0 (from amazon-braket-sdk>=1.76.0->qiskit-braket-provider)
#   Using cached amazon_braket_default_simulator-1.26.4-py3-none-any.whl.metadata (6.5 kB)
# Collecting oqpy~=0.3.5 (from amazon-braket-sdk>=1.76.0->qiskit-braket-provider)
#   Using cached oqpy-0.3.7-py3-none-any.whl.metadata (8.3 kB)
# Collecting backoff (from amazon-braket-sdk>=1.76.0->qiskit-braket-provider)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting boltons (from amazon-braket-sdk>=1.76.0->qiskit-braket-provider)
#   Using cached boltons-25.0.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting boto3>=1.28.53 (from amazon-braket-sdk>=1.76.0->qiskit-braket-provider)
#   Downloading boto3-1.37.33-py3-none-any.whl.metadata (6.7 kB)
# Collecting cloudpickle==2.2.1 (from amazon-braket-sdk>=1.76.0->qiskit-braket-provider)
#   Downloading cloudpickle-2.2.1-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from amazon-braket-sdk>=1.76.0->qiskit-braket-provider) (1.6.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from amazon-braket-sdk>=1.76.0->qiskit-braket-provider) (3.4.2)
# Collecting openpulse (from amazon-braket-sdk>=1.76.0->qiskit-braket-provider)
#   Downloading openpulse-1.0.1-py3-none-any.whl.metadata (2.0 kB)
# Collecting openqasm3 (from amazon-braket-sdk>=1.76.0->qiskit-braket-provider)
#   Downloading openqasm3-1.0.1-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from amazon-braket-sdk>=1.76.0->qiskit-braket-provider) (1.13.1)
# Collecting backports.entry-points-selectable (from amazon-braket-sdk>=1.76.0->qiskit-braket-provider)
#   Downloading backports.entry_points_selectable-1.3.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.11/dist-packages (from qiskit<2.0,>=0.34.2->qiskit-braket-provider) (0.16.0)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.11/dist-packages (from qiskit<2.0,>=0.34.2->qiskit-braket-provider) (1.14.1)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.11/dist-packages (from qiskit<2.0,>=0.34.2->qiskit-braket-provider) (0.3.9)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from qiskit<2.0,>=0.34.2->qiskit-braket-provider) (2.8.2)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from qiskit<2.0,>=0.34.2->qiskit-braket-provider) (5.4.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from qiskit<2.0,>=0.34.2->qiskit-braket-provider) (4.13.1)
# Requirement already satisfied: symengine<0.14,>=0.11 in /usr/local/lib/python3.11/dist-packages (from qiskit<2.0,>=0.34.2->qiskit-braket-provider) (0.13.0)
# Collecting decorator>=5.1.0 (from qiskit-ionq>=0.5.2->qiskit-braket-provider)
#   Downloading decorator-5.2.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: requests>=2.24.0 in /usr/local/lib/python3.11/dist-packages (from qiskit-ionq>=0.5.2->qiskit-braket-provider) (2.32.3)
# Requirement already satisfied: importlib-metadata>=4.11.4 in /usr/local/lib/python3.11/dist-packages (from qiskit-ionq>=0.5.2->qiskit-braket-provider) (8.6.1)
# Collecting python-dotenv>=1.0.1 (from qiskit-ionq>=0.5.2->qiskit-braket-provider)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.11/dist-packages (from amazon-braket-default-simulator>=1.26.0->amazon-braket-sdk>=1.76.0->qiskit-braket-provider) (3.4.0)
# Requirement already satisfied: pydantic>2 in /usr/local/lib/python3.11/dist-packages (from amazon-braket-default-simulator>=1.26.0->amazon-braket-sdk>=1.76.0->qiskit-braket-provider) (2.11.2)
# Collecting antlr4-python3-runtime==4.9.2 (from amazon-braket-default-simulator>=1.26.0->amazon-braket-sdk>=1.76.0->qiskit-braket-provider)
#   Downloading antlr4-python3-runtime-4.9.2.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 kB 5.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting botocore<1.38.0,>=1.37.33 (from boto3>=1.28.53->amazon-braket-sdk>=1.76.0->qiskit-braket-provider)
#   Downloading botocore-1.37.33-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.28.53->amazon-braket-sdk>=1.76.0->qiskit-braket-provider)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.12.0,>=0.11.0 (from boto3>=1.28.53->amazon-braket-sdk>=1.76.0->qiskit-braket-provider)
#   Downloading s3transfer-0.11.4-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=4.11.4->qiskit-ionq>=0.5.2->qiskit-braket-provider) (3.21.0)
# Collecting mypy-extensions>=0.2.0 (from oqpy~=0.3.5->amazon-braket-sdk>=1.76.0->qiskit-braket-provider)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.0->qiskit<2.0,>=0.34.2->qiskit-braket-provider) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.24.0->qiskit-ionq>=0.5.2->qiskit-braket-provider) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.24.0->qiskit-ionq>=0.5.2->qiskit-braket-provider) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.24.0->qiskit-ionq>=0.5.2->qiskit-braket-provider) (2.3.0)
# Requirement already satisfied: pbr>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from stevedore>=3.0.0->qiskit<2.0,>=0.34.2->qiskit-braket-provider) (6.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->amazon-braket-sdk>=1.76.0->qiskit-braket-provider) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>2->amazon-braket-default-simulator>=1.26.0->amazon-braket-sdk>=1.76.0->qiskit-braket-provider) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic>2->amazon-braket-default-simulator>=1.26.0->amazon-braket-sdk>=1.76.0->qiskit-braket-provider) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>2->amazon-braket-default-simulator>=1.26.0->amazon-braket-sdk>=1.76.0->qiskit-braket-provider) (0.4.0)
# Downloading qiskit_braket_provider-0.4.5-py3-none-any.whl (38 kB)
# Downloading amazon_braket_sdk-1.91.0-py3-none-any.whl (317 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.2/317.2 kB 15.1 MB/s eta 0:00:00
# Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Downloading qiskit_ionq-0.5.13-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 kB 4.1 MB/s eta 0:00:00
# Downloading amazon_braket_default_simulator-1.26.4-py3-none-any.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.0/224.0 kB 14.1 MB/s eta 0:00:00
# Downloading amazon_braket_schemas-1.23.3-py3-none-any.whl (132 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.7/132.7 kB 11.0 MB/s eta 0:00:00
# Downloading boto3-1.37.33-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 10.9 MB/s eta 0:00:00
# Downloading decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Downloading oqpy-0.3.7-py3-none-any.whl (36 kB)
# Downloading openpulse-1.0.1-py3-none-any.whl (537 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 537.8/537.8 kB 24.9 MB/s eta 0:00:00
# Downloading openqasm3-1.0.1-py3-none-any.whl (541 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 541.5/541.5 kB 28.9 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading backports.entry_points_selectable-1.3.0-py3-none-any.whl (6.2 kB)
# Downloading boltons-25.0.0-py3-none-any.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.2/194.2 kB 13.5 MB/s eta 0:00:00
# Downloading botocore-1.37.33-py3-none-any.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 90.5 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading s3transfer-0.11.4-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.4/84.4 kB 5.4 MB/s eta 0:00:00
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.2-py3-none-any.whl size=144544 sha256=24da927dfd437ae56773be382ef5e89df816ad84b12af1edf203681d16c41a5e
#   Stored in directory: /root/.cache/pip/wheels/02/5e/de/90c5aab11b66f94cf3f381ec55aaf3f2008213a7056310e25f
# Successfully built antlr4-python3-runtime
# Installing collected packages: openqasm3, antlr4-python3-runtime, python-dotenv, mypy-extensions, jmespath, decorator, cloudpickle, boltons, backports.entry-points-selectable, backoff, openpulse, botocore, s3transfer, oqpy, amazon-braket-schemas, qiskit-ionq, boto3, amazon-braket-default-simulator, amazon-braket-sdk, qiskit-braket-provider
#   Attempting uninstall: decorator
#     Found existing installation: decorator 4.4.2
#     Uninstalling decorator-4.4.2:
#       Successfully uninstalled decorator-4.4.2
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 3.1.1
#     Uninstalling cloudpickle-3.1.1:
#       Successfully uninstalled cloudpickle-3.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# dask 2024.12.1 requires cloudpickle>=3.0.0, but you have cloudpickle 2.2.1 which is incompatible.
# distributed 2024.12.1 requires cloudpickle>=3.0.0, but you have cloudpickle 2.2.1 which is incompatible.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.2.1 which is incompatible.
# Successfully installed amazon-braket-default-simulator-1.26.4 amazon-braket-schemas-1.23.3 amazon-braket-sdk-1.91.0 antlr4-python3-runtime-4.9.2 backoff-2.2.1 backports.entry-points-selectable-1.3.0 boltons-25.0.0 boto3-1.37.33 botocore-1.37.33 cloudpickle-2.2.1 decorator-5.2.1 jmespath-1.0.1 mypy-extensions-1.0.0 openpulse-1.0.1 openqasm3-1.0.1 oqpy-0.3.7 python-dotenv-1.1.0 qiskit-braket-provider-0.4.5 qiskit-ionq-0.5.13 s3transfer-0.11.4
# Collecting amazon-braket-sdk==1.88.3
#   Using cached amazon_braket_sdk-1.88.3-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: amazon-braket-schemas>=1.21.3 in /usr/local/lib/python3.11/dist-packages (from amazon-braket-sdk==1.88.3) (1.23.3)
# Requirement already satisfied: amazon-braket-default-simulator>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from amazon-braket-sdk==1.88.3) (1.26.4)
# Requirement already satisfied: oqpy~=0.3.5 in /usr/local/lib/python3.11/dist-packages (from amazon-braket-sdk==1.88.3) (0.3.7)
# Requirement already satisfied: backoff in /usr/local/lib/python3.11/dist-packages (from amazon-braket-sdk==1.88.3) (2.2.1)
# Requirement already satisfied: boltons in /usr/local/lib/python3.11/dist-packages (from amazon-braket-sdk==1.88.3) (25.0.0)
# Requirement already satisfied: boto3>=1.28.53 in /usr/local/lib/python3.11/dist-packages (from amazon-braket-sdk==1.88.3) (1.37.33)
# Requirement already satisfied: cloudpickle==2.2.1 in /usr/local/lib/python3.11/dist-packages (from amazon-braket-sdk==1.88.3) (2.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from amazon-braket-sdk==1.88.3) (1.6.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from amazon-braket-sdk==1.88.3) (3.4.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from amazon-braket-sdk==1.88.3) (2.0.2)
# Requirement already satisfied: openpulse in /usr/local/lib/python3.11/dist-packages (from amazon-braket-sdk==1.88.3) (1.0.1)
# Requirement already satisfied: openqasm3 in /usr/local/lib/python3.11/dist-packages (from amazon-braket-sdk==1.88.3) (1.0.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from amazon-braket-sdk==1.88.3) (1.13.1)
# Requirement already satisfied: backports.entry-points-selectable in /usr/local/lib/python3.11/dist-packages (from amazon-braket-sdk==1.88.3) (1.3.0)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.11/dist-packages (from amazon-braket-default-simulator>=1.26.0->amazon-braket-sdk==1.88.3) (3.4.0)
# Requirement already satisfied: pydantic>2 in /usr/local/lib/python3.11/dist-packages (from amazon-braket-default-simulator>=1.26.0->amazon-braket-sdk==1.88.3) (2.11.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from amazon-braket-default-simulator>=1.26.0->amazon-braket-sdk==1.88.3) (1.14.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.2 in /usr/local/lib/python3.11/dist-packages (from amazon-braket-default-simulator>=1.26.0->amazon-braket-sdk==1.88.3) (4.9.2)
# Requirement already satisfied: botocore<1.38.0,>=1.37.33 in /usr/local/lib/python3.11/dist-packages (from boto3>=1.28.53->amazon-braket-sdk==1.88.3) (1.37.33)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from boto3>=1.28.53->amazon-braket-sdk==1.88.3) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from boto3>=1.28.53->amazon-braket-sdk==1.88.3) (0.11.4)
# Requirement already satisfied: mypy-extensions>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from oqpy~=0.3.5->amazon-braket-sdk==1.88.3) (1.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->amazon-braket-sdk==1.88.3) (1.3.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.11/dist-packages (from botocore<1.38.0,>=1.37.33->boto3>=1.28.53->amazon-braket-sdk==1.88.3) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from botocore<1.38.0,>=1.37.33->boto3>=1.28.53->amazon-braket-sdk==1.88.3) (2.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>2->amazon-braket-default-simulator>=1.26.0->amazon-braket-sdk==1.88.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic>2->amazon-braket-default-simulator>=1.26.0->amazon-braket-sdk==1.88.3) (2.33.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>2->amazon-braket-default-simulator>=1.26.0->amazon-braket-sdk==1.88.3) (4.13.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>2->amazon-braket-default-simulator>=1.26.0->amazon-braket-sdk==1.88.3) (0.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.38.0,>=1.37.33->boto3>=1.28.53->amazon-braket-sdk==1.88.3) (1.17.0)
# Downloading amazon_braket_sdk-1.88.3-py3-none-any.whl (315 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.6/315.6 kB 6.1 MB/s eta 0:00:00
# Installing collected packages: amazon-braket-sdk
#   Attempting uninstall: amazon-braket-sdk
#     Found existing installation: amazon-braket-sdk 1.91.0
#     Uninstalling amazon-braket-sdk-1.91.0:
#       Successfully uninstalled amazon-braket-sdk-1.91.0
# Successfully installed amazon-braket-sdk-1.88.3

# %%
# Use Braket SDK Cost Tracking to estimate the cost to run this example
from braket.tracking import Tracker
t = Tracker().start()

# %%
import os
# Set environment variables for AWS credentials
os.environ['AWS_ACCESS_KEY_ID'] = ""
os.environ['AWS_SECRET_ACCESS_KEY'] = "+"
os.environ['AWS_DEFAULT_REGION'] = "us-east-1"

# You can optionally set the s3 bucket and prefix using environment variables
#os.environ['AWS_BRAKET_S3_BUCKET'] = "snuqc"
#os.environ['AWS_BRAKET_S3_PREFIX'] = "amazonbraket"

# %%
from qiskit_braket_provider import BraketProvider

provider = BraketProvider()
provider.backends(statuses=["ONLINE"], types=["QPU"])
print(provider.backends())
# Out:
# [BraketBackend[Ankaa-3], BraketBackend[Aria 1], BraketBackend[Aria 2], BraketBackend[Forte 1], BraketBackend[Forte Enterprise 1], BraketBackend[Garnet], BraketBackend[SV1], BraketBackend[TN1], BraketBackend[dm1]]

# %%
backend = provider.get_backend("Aria 1")
#backend = provider.get_backend("Aria 2")
#backend = provider.get_backend("Forte 1")

#backend= provider.get_backend("Ankaa-2")
#backend = provider.get_backend("Aspen-M-3")

#Ibackend = provider.get_backend("Garnet")

#backend = provider.get_backend("SV1")
#backend = provider.get_backend("dm1")
#backend = provider.get_backend("TN1")

# %%
from qiskit import QuantumCircuit

circuit = QuantumCircuit(3)
circuit.h(0)
circuit.cx(0, 1)
circuit.measure_all()

# %%
circuit.draw("mpl")

# %%
from qiskit.compiler import transpile, assemble
trans_qc = transpile(circuit, backend)
trans_qc.draw("mpl")

# %%
from qiskit.providers.jobstatus import JobStatus
import time

job = backend.run(trans_qc, shots=1024)

print("Job ID is", job.job_id(),"\n")

# 제출된 잡에 대한 지속적인 실행 상태 확인
#while job.status() is not JobStatus.DONE:
#	print("Job status is", job.status() )
#	time.sleep(2)
###while
# Out:
# /usr/local/lib/python3.11/dist-packages/qiskit_braket_provider/providers/adapter.py:521: UserWarning: The Qiskit circuit contains barrier instructions that are ignored.
#   warnings.warn(
# Job ID is arn:aws:braket:us-east-1:590183937332:quantum-task/9d253008-c88d-4ade-82e9-a120436b5388

# %%
print("Job status is", job.status())
# Out:
# Job status is JobStatus.DONE

# %%
# 중간에 세션이 종료된 경우 기존에 실행이 완료된 Job을 복구하는 방법
#job = backend.retrieve_job("arn:aws:braket:us-east-1:746669231099:quantum-task/f6fab6be-1590-4da0-914a-fade74efc485")

# %%
result = job.result()
result
# Out:
# Result(backend_name='Aria 1', backend_version='2', qobj_id='0', job_id='arn:aws:braket:us-east-1:590183937332:quantum-task/9d253008-c88d-4ade-82e9-a120436b5388', success=True, results=[ExperimentResult(shots=1024, success=True, meas_level=2, data=ExperimentResultData(counts={'000': 500, '001': 8, '010': 10, '011': 506}, memory=['000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '000', '001', '001', '001', '001', '001', '001', '001', '001', '010', '010', '010', '010', '010', '010', '010', '010', '010', '010', '011', '011', '011', '011', '011', '011', '0 ...

# %%
# 결과 출력
counts = result.get_counts()
print(counts)
# Out:
# {'000': 500, '001': 8, '010': 10, '011': 506}

# %%
from qiskit.visualization import plot_histogram
plot_histogram(data=counts)

# %%
print("Quantum Task Summary\n")
print(t.quantum_tasks_statistics())
print('\nNote: Charges shown are estimates based on your Amazon Braket simulator and quantum processing unit (QPU) task usage. \nEstimated charges shown may differ from your actual charges. \nEstimated charges do not factor in any discounts or credits, \nand you may experience additional charges based on your use of other services such as Amazon Elastic Compute Cloud (Amazon EC2).')
print(f"\nEstimated cost to run this example: {t.qpu_tasks_cost() + t.simulator_tasks_cost():.2f} USD")
# Out:
# Quantum Task Summary
#
# {'arn:aws:braket:us-east-1::device/qpu/ionq/Aria-1': {'shots': 1024, 'tasks': {'COMPLETED': 1}}}
#
# Note: Charges shown are estimates based on your Amazon Braket simulator and quantum processing unit (QPU) task usage.
# Estimated charges shown may differ from your actual charges.
# Estimated charges do not factor in any discounts or credits,
# and you may experience additional charges based on your use of other services such as Amazon Elastic Compute Cloud (Amazon EC2).
#
# Estimated cost to run this example: 31.02 USD
